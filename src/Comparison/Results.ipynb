# %%
import sys
sys.path.append(r'/Users/gabriellebouvier/SIR_Model/src/Particles')

# %%
import arviz as az
import numpy as np
from Functions import summary
from Functions import weighted_ess
import matplotlib
from matplotlib import pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sb
import pickle

# %% [markdown]
# # PMMH

# %% [markdown]
# ## Open files

# %%
# Load data
pmmh_posteriors_1 = np.load("pmmh_posteriors_1.npz")
pmmh_posteriors_2 = np.load("pmmh_posteriors_2.npz")
pmmh_posteriors_3 = np.load("pmmh_posteriors_3.npz")
pmmh_posteriors_4 = np.load("pmmh_posteriors_4.npz")
pmmh_posteriors_5 = np.load("pmmh_posteriors_5.npz")
pmmh_posteriors_6 = np.load("pmmh_posteriors_6.npz")
pmmh_posteriors_7 = np.load("pmmh_posteriors_7.npz")
pmmh_posteriors_8 = np.load("pmmh_posteriors_8.npz")
pmmh_posteriors_9 = np.load("pmmh_posteriors_9.npz")
pmmh_posteriors_10 = np.load("pmmh_posteriors_10.npz")

pmmh_20 = np.load("pmmh_20.npz")
abcsmc_20 = np.load("abcsmc_20.npz")

abcsmc_20 = np.load("abcsmc_20.npz")

# %%
# pmmh_posteriors_1
pmmh_beta_1_1 = pmmh_posteriors_1['arr0']
pmmh_beta_1_2 = pmmh_posteriors_1['arr1']
pmmh_beta_1_3 = pmmh_posteriors_1['arr2']
pmmh_beta_1_4 = pmmh_posteriors_1['arr3']

pmmh_gamma_1_1 = pmmh_posteriors_1['arr4']
pmmh_gamma_1_2 = pmmh_posteriors_1['arr5']
pmmh_gamma_1_3 = pmmh_posteriors_1['arr6']
pmmh_gamma_1_4 = pmmh_posteriors_1['arr7']

# pmmh_posteriors_2
pmmh_beta_2_1 = pmmh_posteriors_2['arr0']
pmmh_beta_2_2 = pmmh_posteriors_2['arr1']
pmmh_beta_2_3 = pmmh_posteriors_2['arr2']
pmmh_beta_2_4 = pmmh_posteriors_2['arr3']

pmmh_gamma_2_1 = pmmh_posteriors_2['arr4']
pmmh_gamma_2_2 = pmmh_posteriors_2['arr5']
pmmh_gamma_2_3 = pmmh_posteriors_2['arr6']
pmmh_gamma_2_4 = pmmh_posteriors_2['arr7']

# pmmh_posteriors_3
pmmh_beta_3_1 = pmmh_posteriors_3['arr0']
pmmh_beta_3_2 = pmmh_posteriors_3['arr1']
pmmh_beta_3_3 = pmmh_posteriors_3['arr2']
pmmh_beta_3_4 = pmmh_posteriors_3['arr3']

pmmh_gamma_3_1 = pmmh_posteriors_3['arr4']
pmmh_gamma_3_2 = pmmh_posteriors_3['arr5']
pmmh_gamma_3_3 = pmmh_posteriors_3['arr6']
pmmh_gamma_3_4 = pmmh_posteriors_3['arr7']

# pmmh_posteriors_4
pmmh_beta_4_1 = pmmh_posteriors_4['arr0']
pmmh_beta_4_2 = pmmh_posteriors_4['arr1']
pmmh_beta_4_3 = pmmh_posteriors_4['arr2']
pmmh_beta_4_4 = pmmh_posteriors_4['arr3']

pmmh_gamma_4_1 = pmmh_posteriors_4['arr4']
pmmh_gamma_4_2 = pmmh_posteriors_4['arr5']
pmmh_gamma_4_3 = pmmh_posteriors_4['arr6']
pmmh_gamma_4_4 = pmmh_posteriors_4['arr7']

# pmmh_posteriors_5
pmmh_beta_5_1 = pmmh_posteriors_5['arr0']
pmmh_beta_5_2 = pmmh_posteriors_5['arr1']
pmmh_beta_5_3 = pmmh_posteriors_5['arr2']
pmmh_beta_5_4 = pmmh_posteriors_5['arr3']

pmmh_gamma_5_1 = pmmh_posteriors_5['arr4']
pmmh_gamma_5_2 = pmmh_posteriors_5['arr5']
pmmh_gamma_5_3 = pmmh_posteriors_5['arr6']
pmmh_gamma_5_4 = pmmh_posteriors_5['arr7']

# pmmh_posteriors_6
pmmh_beta_6_1 = pmmh_posteriors_6['arr0']
pmmh_beta_6_2 = pmmh_posteriors_6['arr1']
pmmh_beta_6_3 = pmmh_posteriors_6['arr2']
pmmh_beta_6_4 = pmmh_posteriors_6['arr3']

pmmh_gamma_6_1 = pmmh_posteriors_6['arr4']
pmmh_gamma_6_2 = pmmh_posteriors_6['arr5']
pmmh_gamma_6_3 = pmmh_posteriors_6['arr6']
pmmh_gamma_6_4 = pmmh_posteriors_6['arr7']

# pmmh_posteriors_7
pmmh_beta_7_1 = pmmh_posteriors_7['arr0']
pmmh_beta_7_2 = pmmh_posteriors_7['arr1']
pmmh_beta_7_3 = pmmh_posteriors_7['arr2']
pmmh_beta_7_4 = pmmh_posteriors_7['arr3']

pmmh_gamma_7_1 = pmmh_posteriors_7['arr4']
pmmh_gamma_7_2 = pmmh_posteriors_7['arr5']
pmmh_gamma_7_3 = pmmh_posteriors_7['arr6']
pmmh_gamma_7_4 = pmmh_posteriors_7['arr7']

# pmmh_posteriors_8
pmmh_beta_8_1 = pmmh_posteriors_8['arr0']
pmmh_beta_8_2 = pmmh_posteriors_8['arr1']
pmmh_beta_8_3 = pmmh_posteriors_8['arr2']
pmmh_beta_8_4 = pmmh_posteriors_8['arr3']

pmmh_gamma_8_1 = pmmh_posteriors_8['arr4']
pmmh_gamma_8_2 = pmmh_posteriors_8['arr5']
pmmh_gamma_8_3 = pmmh_posteriors_8['arr6']
pmmh_gamma_8_4 = pmmh_posteriors_8['arr7']

# pmmh_posteriors_9
pmmh_beta_9_1 = pmmh_posteriors_9['arr0']
pmmh_beta_9_2 = pmmh_posteriors_9['arr1']
pmmh_beta_9_3 = pmmh_posteriors_9['arr2']
pmmh_beta_9_4 = pmmh_posteriors_9['arr3']

pmmh_gamma_9_1 = pmmh_posteriors_9['arr4']
pmmh_gamma_9_2 = pmmh_posteriors_9['arr5']
pmmh_gamma_9_3 = pmmh_posteriors_9['arr6']
pmmh_gamma_9_4 = pmmh_posteriors_9['arr7']

# pmmh_posteriors_10
pmmh_beta_10_1 = pmmh_posteriors_10['arr0']
pmmh_beta_10_2 = pmmh_posteriors_10['arr1']
pmmh_beta_10_3 = pmmh_posteriors_10['arr2']
pmmh_beta_10_4 = pmmh_posteriors_10['arr3']

pmmh_gamma_10_1 = pmmh_posteriors_10['arr4']
pmmh_gamma_10_2 = pmmh_posteriors_10['arr5']
pmmh_gamma_10_3 = pmmh_posteriors_10['arr6']
pmmh_gamma_10_4 = pmmh_posteriors_10['arr7']

# %%
print(len(pmmh_beta_3_2))
# Out:
# 4000

# %%
# Posterior distribution arrays
pmcmc_beta_1 = np.array([pmmh_beta_1_1, pmmh_beta_1_2, pmmh_beta_1_3, pmmh_beta_1_4])
pmcmc_gamma_1 = np.array([pmmh_gamma_1_1, pmmh_gamma_1_2, pmmh_gamma_1_3, pmmh_gamma_1_4])

pmcmc_beta_2 = np.array([pmmh_beta_2_1, pmmh_beta_2_2, pmmh_beta_2_3, pmmh_beta_2_4])
pmcmc_gamma_2 = np.array([pmmh_gamma_2_1, pmmh_gamma_2_2, pmmh_gamma_2_3, pmmh_gamma_2_4])

pmcmc_beta_3 = np.array([pmmh_beta_3_1, pmmh_beta_3_2, pmmh_beta_3_3, pmmh_beta_3_4])
pmcmc_gamma_3 = np.array([pmmh_gamma_3_1, pmmh_gamma_3_2, pmmh_gamma_3_3, pmmh_gamma_3_4])

pmcmc_beta_4 = np.array([pmmh_beta_4_1, pmmh_beta_4_2, pmmh_beta_4_3, pmmh_beta_4_4])
pmcmc_gamma_4 = np.array([pmmh_gamma_4_1, pmmh_gamma_4_2, pmmh_gamma_4_3, pmmh_gamma_4_4])

pmcmc_beta_5 = np.array([pmmh_beta_5_1, pmmh_beta_5_2, pmmh_beta_5_3, pmmh_beta_5_4])
pmcmc_gamma_5 = np.array([pmmh_gamma_5_1, pmmh_gamma_5_2, pmmh_gamma_5_3, pmmh_gamma_5_4])

pmcmc_beta_6 = np.array([pmmh_beta_6_1, pmmh_beta_6_2, pmmh_beta_6_3, pmmh_beta_6_4])
pmcmc_gamma_6 = np.array([pmmh_gamma_6_1, pmmh_gamma_6_2, pmmh_gamma_6_3, pmmh_gamma_6_4])

pmcmc_beta_7 = np.array([pmmh_beta_7_1, pmmh_beta_7_2, pmmh_beta_7_3, pmmh_beta_7_4])
pmcmc_gamma_7 = np.array([pmmh_gamma_7_1, pmmh_gamma_7_2, pmmh_gamma_7_3, pmmh_gamma_7_4])

pmcmc_beta_8 = np.array([pmmh_beta_8_1, pmmh_beta_8_2, pmmh_beta_8_3, pmmh_beta_8_4])
pmcmc_gamma_8 = np.array([pmmh_gamma_8_1, pmmh_gamma_8_2, pmmh_gamma_8_3, pmmh_gamma_8_4])

pmcmc_beta_9 = np.array([pmmh_beta_9_1, pmmh_beta_9_2, pmmh_beta_9_3, pmmh_beta_9_4])
pmcmc_gamma_9 = np.array([pmmh_gamma_9_1, pmmh_gamma_9_2, pmmh_gamma_9_3, pmmh_gamma_9_4])

pmcmc_beta_10 = np.array([pmmh_beta_10_1, pmmh_beta_10_2, pmmh_beta_10_3, pmmh_beta_10_4])
pmcmc_gamma_10 = np.array([pmmh_gamma_10_1, pmmh_gamma_10_2, pmmh_gamma_10_3, pmmh_gamma_10_4])

# %% [markdown]
# ## Summary results

# %%
pmcmc_1 = summary('Beta', 'Gamma', pmcmc_beta_1, pmcmc_gamma_1, 4)
pmcmc_2 = summary('Beta', 'Gamma', pmcmc_beta_2, pmcmc_gamma_2, 4)
pmcmc_3 = summary('Beta', 'Gamma', pmcmc_beta_3, pmcmc_gamma_3, 4)
pmcmc_4 = summary('Beta', 'Gamma', pmcmc_beta_4, pmcmc_gamma_4, 4)
pmcmc_5 = summary('Beta', 'Gamma', pmcmc_beta_5, pmcmc_gamma_5, 4)
pmcmc_6 = summary('Beta', 'Gamma', pmcmc_beta_6, pmcmc_gamma_6, 4)
pmcmc_7 = summary('Beta', 'Gamma', pmcmc_beta_7, pmcmc_gamma_7, 4)
pmcmc_8 = summary('Beta', 'Gamma', pmcmc_beta_8, pmcmc_gamma_8, 4)
pmcmc_9 = summary('Beta', 'Gamma', pmcmc_beta_9, pmcmc_gamma_9, 4)
pmcmc_10 = summary('Beta', 'Gamma', pmcmc_beta_10, pmcmc_gamma_10, 4)
# Out:
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      Beta  0.4438    0.0009  0.0304    0.3939    0.4915    0.3926    0.4896
# 1     Gamma  0.1071    0.0008  0.0277    0.0648    0.1525    0.0646    0.1521
#
#     ess_bulk   ess_tail    rhat  mcse_mean  mcse_std
# 0  2421.4535  2825.1071  1.0018     0.0006    0.0004
# 1  2298.3929  2697.1908  1.0026     0.0006    0.0004
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      Beta  0.5738    0.1159  0.3404    0.3512    1.1623    0.3592    1.1623
# 1     Gamma  0.4453    0.3965  0.6297    0.0639    1.5356    0.0639    1.5356
#
#    ess_bulk  ess_tail    rhat  mcse_mean  mcse_std
# 0    5.1247   52.3865  2.2614     0.1700    0.0978
# 1    4.8432    4.7642  4.7912     0.3145    0.1815
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      Beta  0.4533    0.0009  0.0299    0.4055    0.5007    0.4057    0.5007
# ...

# %% [markdown]
# # ABC-SMC

# %% [markdown]
# ## Open files

# %%
# Load data
abcsmc_posteriors_1 = np.load("abcsmc_posteriors_1.npz")
abcsmc_posteriors_2 = np.load("abcsmc_posteriors_2.npz")
abcsmc_posteriors_3 = np.load("abcsmc_posteriors_3.npz")
abcsmc_posteriors_4 = np.load("abcsmc_posteriors_4.npz")
abcsmc_posteriors_5 = np.load("abcsmc_posteriors_5.npz")
abcsmc_posteriors_6 = np.load("abcsmc_posteriors_6.npz")
abcsmc_posteriors_7 = np.load("abcsmc_posteriors_7.npz")
abcsmc_posteriors_8 = np.load("abcsmc_posteriors_8.npz")
abcsmc_posteriors_9 = np.load("abcsmc_posteriors_9.npz")
abcsmc_posteriors_10 = np.load("abcsmc_posteriors_10.npz")

# %%
# abcsmc_posteriors_1
abcsmc_beta_1_1 = abcsmc_posteriors_1['arr0']
abcsmc_beta_1_2 = abcsmc_posteriors_1['arr1']
abcsmc_beta_1_3 = abcsmc_posteriors_1['arr2']
abcsmc_beta_1_4 = abcsmc_posteriors_1['arr3']

abcsmc_gamma_1_1 = abcsmc_posteriors_1['arr4']
abcsmc_gamma_1_2 = abcsmc_posteriors_1['arr5']
abcsmc_gamma_1_3 = abcsmc_posteriors_1['arr6']
abcsmc_gamma_1_4 = abcsmc_posteriors_1['arr7']

# abcsmc_posteriors_2
abcsmc_beta_2_1 = abcsmc_posteriors_2['arr0']
abcsmc_beta_2_2 = abcsmc_posteriors_2['arr1']
abcsmc_beta_2_3 = abcsmc_posteriors_2['arr2']
abcsmc_beta_2_4 = abcsmc_posteriors_2['arr3']

abcsmc_gamma_2_1 = abcsmc_posteriors_2['arr4']
abcsmc_gamma_2_2 = abcsmc_posteriors_2['arr5']
abcsmc_gamma_2_3 = abcsmc_posteriors_2['arr6']
abcsmc_gamma_2_4 = abcsmc_posteriors_2['arr7']

# abcsmc_posteriors_3
abcsmc_beta_3_1 = abcsmc_posteriors_3['arr0']
abcsmc_beta_3_2 = abcsmc_posteriors_3['arr1']
abcsmc_beta_3_3 = abcsmc_posteriors_3['arr2']
abcsmc_beta_3_4 = abcsmc_posteriors_3['arr3']

abcsmc_gamma_3_1 = abcsmc_posteriors_3['arr4']
abcsmc_gamma_3_2 = abcsmc_posteriors_3['arr5']
abcsmc_gamma_3_3 = abcsmc_posteriors_3['arr6']
abcsmc_gamma_3_4 = abcsmc_posteriors_3['arr7']

# abcsmc_posteriors_4
abcsmc_beta_4_1 = abcsmc_posteriors_4['arr0']
abcsmc_beta_4_2 = abcsmc_posteriors_4['arr1']
abcsmc_beta_4_3 = abcsmc_posteriors_4['arr2']
abcsmc_beta_4_4 = abcsmc_posteriors_4['arr3']

abcsmc_gamma_4_1 = abcsmc_posteriors_4['arr4']
abcsmc_gamma_4_2 = abcsmc_posteriors_4['arr5']
abcsmc_gamma_4_3 = abcsmc_posteriors_4['arr6']
abcsmc_gamma_4_4 = abcsmc_posteriors_4['arr7']

# abcsmc_posteriors_5
abcsmc_beta_5_1 = abcsmc_posteriors_5['arr0']
abcsmc_beta_5_2 = abcsmc_posteriors_5['arr1']
abcsmc_beta_5_3 = abcsmc_posteriors_5['arr2']
abcsmc_beta_5_4 = abcsmc_posteriors_5['arr3']

abcsmc_gamma_5_1 = abcsmc_posteriors_5['arr4']
abcsmc_gamma_5_2 = abcsmc_posteriors_5['arr5']
abcsmc_gamma_5_3 = abcsmc_posteriors_5['arr6']
abcsmc_gamma_5_4 = abcsmc_posteriors_5['arr7']

# abcsmc_posteriors_6
abcsmc_beta_6_1 = abcsmc_posteriors_6['arr0']
abcsmc_beta_6_2 = abcsmc_posteriors_6['arr1']
abcsmc_beta_6_3 = abcsmc_posteriors_6['arr2']
abcsmc_beta_6_4 = abcsmc_posteriors_6['arr3']

abcsmc_gamma_6_1 = abcsmc_posteriors_6['arr4']
abcsmc_gamma_6_2 = abcsmc_posteriors_6['arr5']
abcsmc_gamma_6_3 = abcsmc_posteriors_6['arr6']
abcsmc_gamma_6_4 = abcsmc_posteriors_6['arr7']

# abcsmc_posteriors_7
abcsmc_beta_7_1 = abcsmc_posteriors_7['arr0']
abcsmc_beta_7_2 = abcsmc_posteriors_7['arr1']
abcsmc_beta_7_3 = abcsmc_posteriors_7['arr2']
abcsmc_beta_7_4 = abcsmc_posteriors_7['arr3']

abcsmc_gamma_7_1 = abcsmc_posteriors_7['arr4']
abcsmc_gamma_7_2 = abcsmc_posteriors_7['arr5']
abcsmc_gamma_7_3 = abcsmc_posteriors_7['arr6']
abcsmc_gamma_7_4 = abcsmc_posteriors_7['arr7']

# abcsmc_posteriors_8
abcsmc_beta_8_1 = abcsmc_posteriors_8['arr0']
abcsmc_beta_8_2 = abcsmc_posteriors_8['arr1']
abcsmc_beta_8_3 = abcsmc_posteriors_8['arr2']
abcsmc_beta_8_4 = abcsmc_posteriors_8['arr3']

abcsmc_gamma_8_1 = abcsmc_posteriors_8['arr4']
abcsmc_gamma_8_2 = abcsmc_posteriors_8['arr5']
abcsmc_gamma_8_3 = abcsmc_posteriors_8['arr6']
abcsmc_gamma_8_4 = abcsmc_posteriors_8['arr7']

# abcsmc_posteriors_9
abcsmc_beta_9_1 = abcsmc_posteriors_9['arr0']
abcsmc_beta_9_2 = abcsmc_posteriors_9['arr1']
abcsmc_beta_9_3 = abcsmc_posteriors_9['arr2']
abcsmc_beta_9_4 = abcsmc_posteriors_9['arr3']

abcsmc_gamma_9_1 = abcsmc_posteriors_9['arr4']
abcsmc_gamma_9_2 = abcsmc_posteriors_9['arr5']
abcsmc_gamma_9_3 = abcsmc_posteriors_9['arr6']
abcsmc_gamma_9_4 = abcsmc_posteriors_9['arr7']

# abcsmc_posteriors_10
abcsmc_beta_10_1 = abcsmc_posteriors_10['arr0']
abcsmc_beta_10_2 = abcsmc_posteriors_10['arr1']
abcsmc_beta_10_3 = abcsmc_posteriors_10['arr2']
abcsmc_beta_10_4 = abcsmc_posteriors_10['arr3']

abcsmc_gamma_10_1 = abcsmc_posteriors_10['arr4']
abcsmc_gamma_10_2 = abcsmc_posteriors_10['arr5']
abcsmc_gamma_10_3 = abcsmc_posteriors_10['arr6']
abcsmc_gamma_10_4 = abcsmc_posteriors_10['arr7']

# %%
# Posterior distribution arrays
abcsmc_beta_1 = np.array([abcsmc_beta_1_1, abcsmc_beta_1_2, abcsmc_beta_1_3, abcsmc_beta_1_4])
abcsmc_gamma_1 = np.array([abcsmc_gamma_1_1, abcsmc_gamma_1_2, abcsmc_gamma_1_3, abcsmc_gamma_1_4])

abcsmc_beta_2 = np.array([abcsmc_beta_2_1, abcsmc_beta_2_2, abcsmc_beta_2_3, abcsmc_beta_2_4])
abcsmc_gamma_2 = np.array([abcsmc_gamma_2_1, abcsmc_gamma_2_2, abcsmc_gamma_2_3, abcsmc_gamma_2_4])

abcsmc_beta_3 = np.array([abcsmc_beta_3_1, abcsmc_beta_3_2, abcsmc_beta_3_3, abcsmc_beta_3_4])
abcsmc_gamma_3 = np.array([abcsmc_gamma_3_1, abcsmc_gamma_3_2, abcsmc_gamma_3_3, abcsmc_gamma_3_4])

abcsmc_beta_4 = np.array([abcsmc_beta_4_1, abcsmc_beta_4_2, abcsmc_beta_4_3, abcsmc_beta_4_4])
abcsmc_gamma_4 = np.array([abcsmc_gamma_4_1, abcsmc_gamma_4_2, abcsmc_gamma_4_3, abcsmc_gamma_4_4])

abcsmc_beta_5 = np.array([abcsmc_beta_5_1, abcsmc_beta_5_2, abcsmc_beta_5_3, abcsmc_beta_5_4])
abcsmc_gamma_5 = np.array([abcsmc_gamma_5_1, abcsmc_gamma_5_2, abcsmc_gamma_5_3, abcsmc_gamma_5_4])

abcsmc_beta_6 = np.array([abcsmc_beta_6_1, abcsmc_beta_6_2, abcsmc_beta_6_3, abcsmc_beta_6_4])
abcsmc_gamma_6 = np.array([abcsmc_gamma_6_1, abcsmc_gamma_6_2, abcsmc_gamma_6_3, abcsmc_gamma_6_4])

abcsmc_beta_7 = np.array([abcsmc_beta_7_1, abcsmc_beta_7_2, abcsmc_beta_7_3, abcsmc_beta_7_4])
abcsmc_gamma_7 = np.array([abcsmc_gamma_7_1, abcsmc_gamma_7_2, abcsmc_gamma_7_3, abcsmc_gamma_7_4])

abcsmc_beta_8 = np.array([abcsmc_beta_8_1, abcsmc_beta_8_2, abcsmc_beta_8_3, abcsmc_beta_8_4])
abcsmc_gamma_8 = np.array([abcsmc_gamma_8_1, abcsmc_gamma_8_2, abcsmc_gamma_8_3, abcsmc_gamma_8_4])

abcsmc_beta_9 = np.array([abcsmc_beta_9_1, abcsmc_beta_9_2, abcsmc_beta_9_3, abcsmc_beta_9_4])
abcsmc_gamma_9 = np.array([abcsmc_gamma_9_1, abcsmc_gamma_9_2, abcsmc_gamma_9_3, abcsmc_gamma_9_4])

abcsmc_beta_10 = np.array([abcsmc_beta_10_1, abcsmc_beta_10_2, abcsmc_beta_10_3, abcsmc_beta_10_4])
abcsmc_gamma_10 = np.array([abcsmc_gamma_10_1, abcsmc_gamma_10_2, abcsmc_gamma_10_3, abcsmc_gamma_10_4])

# %% [markdown]
# ## Summary results

# %%
print(type(abcsmc_beta_10))
# Out:
# <class 'numpy.ndarray'>

# %%
abcsmc_1 = summary('Beta', 'Gamma', abcsmc_beta_1, abcsmc_gamma_1, 4)
abcsmc_2 = summary('Beta', 'Gamma', abcsmc_beta_2, abcsmc_gamma_2, 4)
abcsmc_3 = summary('Beta', 'Gamma', abcsmc_beta_3, abcsmc_gamma_3, 4)
abcsmc_4 = summary('Beta', 'Gamma', abcsmc_beta_4, abcsmc_gamma_4, 4)
abcsmc_5 = summary('Beta', 'Gamma', abcsmc_beta_5, abcsmc_gamma_5, 4)
abcsmc_6 = summary('Beta', 'Gamma', abcsmc_beta_6, abcsmc_gamma_6, 4)
abcsmc_7 = summary('Beta', 'Gamma', abcsmc_beta_7, abcsmc_gamma_7, 4)
abcsmc_8 = summary('Beta', 'Gamma', abcsmc_beta_8, abcsmc_gamma_8, 4)
abcsmc_9 = summary('Beta', 'Gamma', abcsmc_beta_9, abcsmc_gamma_9, 4)
abcsmc_10 = summary('Beta', 'Gamma', abcsmc_beta_10, abcsmc_gamma_10, 4)
# Out:
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      Beta  0.4697    0.0028  0.0532    0.3893    0.5607    0.3802    0.5475
# 1     Gamma   0.112    0.0042  0.0645    0.0206    0.2266    0.0026    0.1978
#
#     ess_bulk   ess_tail    rhat  mcse_mean  mcse_std
# 0  3822.0914  3811.3622  1.0008     0.0009    0.0006
# 1  3772.3752  3972.5607  1.0010     0.0010    0.0007
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      Beta  0.4371    0.0020  0.0449    0.3708    0.5121    0.3680    0.5085
# 1     Gamma  0.0822    0.0024  0.0489    0.0132    0.1657    0.0045    0.1502
#
#    ess_bulk   ess_tail    rhat  mcse_mean  mcse_std
# 0  4047.229  4012.2416  0.9999     0.0007    0.0005
# 1  4063.286  3874.7213  1.0003     0.0008    0.0006
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      Beta  0.4634    0.0023   0.048    0.3903    0.5434    0.3858    0.5375
# ...

# %% [markdown]
# # Posterior Distributions

# %%
# Test 1
hdi_beta_1 = az.hdi(pmcmc_beta_1.flatten())
hdi_gamma_1 = az.hdi(pmcmc_gamma_1.flatten())

beta_mean_1 = az.mean(pmcmc_beta_1, round_to=4)
gamma_mean_1 = az.mean(pmcmc_gamma_1, round_to=4)

# Test 2
hdi_beta_2 = az.hdi(pmcmc_beta_2.flatten())
hdi_gamma_2 = az.hdi(pmcmc_gamma_2.flatten())

beta_mean_2 = az.mean(pmcmc_beta_2, round_to=4)
gamma_mean_2 = az.mean(pmcmc_gamma_2, round_to=4)

# Test 3
hdi_beta_3 = az.hdi(pmcmc_beta_3.flatten())
hdi_gamma_3 = az.hdi(pmcmc_gamma_3.flatten())

beta_mean_3 = az.mean(pmcmc_beta_3, round_to=4)
gamma_mean_3 = az.mean(pmcmc_gamma_3, round_to=4)

# Test 4
hdi_beta_4 = az.hdi(pmcmc_beta_4.flatten())
hdi_gamma_4 = az.hdi(pmcmc_gamma_4.flatten())

beta_mean_4 = az.mean(pmcmc_beta_4, round_to=4)
gamma_mean_4 = az.mean(pmcmc_gamma_4, round_to=4)

# Test 5
hdi_beta_5 = az.hdi(pmcmc_beta_5.flatten())
hdi_gamma_5 = az.hdi(pmcmc_gamma_5.flatten())

beta_mean_5 = az.mean(pmcmc_beta_5, round_to=4)
gamma_mean_5 = az.mean(pmcmc_gamma_5, round_to=4)

# Test 6
hdi_beta_6 = az.hdi(pmcmc_beta_6.flatten())
hdi_gamma_6 = az.hdi(pmcmc_gamma_6.flatten())

beta_mean_6 = az.mean(pmcmc_beta_6, round_to=4)
gamma_mean_6 = az.mean(pmcmc_gamma_6, round_to=4)

# Test 7
hdi_beta_7 = az.hdi(pmcmc_beta_7.flatten())
hdi_gamma_7 = az.hdi(pmcmc_gamma_7.flatten())

beta_mean_7 = az.mean(pmcmc_beta_7, round_to=4)
gamma_mean_7 = az.mean(pmcmc_gamma_7, round_to=4)

# Test 8
hdi_beta_8 = az.hdi(pmcmc_beta_8.flatten())
hdi_gamma_8 = az.hdi(pmcmc_gamma_8.flatten())

beta_mean_8 = az.mean(pmcmc_beta_8, round_to=4)
gamma_mean_8 = az.mean(pmcmc_gamma_8, round_to=4)

# Test 9
hdi_beta_9 = az.hdi(pmcmc_beta_9.flatten())
hdi_gamma_9 = az.hdi(pmcmc_gamma_9.flatten())

beta_mean_9 = az.mean(pmcmc_beta_9, round_to=4)
gamma_mean_9 = az.mean(pmcmc_gamma_9, round_to=4)

# Test 10
hdi_beta_10 = az.hdi(pmcmc_beta_10.flatten())
hdi_gamma_10 = az.hdi(pmcmc_gamma_10.flatten())

beta_mean_10 = az.mean(pmcmc_beta_10, round_to=4)
gamma_mean_10 = az.mean(pmcmc_gamma_10, round_to=4)

# %%
# Test 1
a_hdi_beta_1 = az.hdi(abcsmc_beta_1.flatten())
a_hdi_gamma_1 = az.hdi(abcsmc_gamma_1.flatten())

a_beta_mean_1 = az.mean(abcsmc_beta_1, round_to=4)
a_gamma_mean_1 = az.mean(abcsmc_gamma_1, round_to=4)

# Test 2
a_hdi_beta_2 = az.hdi(abcsmc_beta_2.flatten())
a_hdi_gamma_2 = az.hdi(abcsmc_gamma_2.flatten())

a_beta_mean_2 = az.mean(abcsmc_beta_2, round_to=4)
a_gamma_mean_2 = az.mean(abcsmc_gamma_2, round_to=4)

# Test 3
a_hdi_beta_3 = az.hdi(abcsmc_beta_3.flatten())
a_hdi_gamma_3 = az.hdi(abcsmc_gamma_3.flatten())

a_beta_mean_3 = az.mean(abcsmc_beta_3, round_to=4)
a_gamma_mean_3 = az.mean(abcsmc_gamma_3, round_to=4)

# Test 4
a_hdi_beta_4 = az.hdi(abcsmc_beta_4.flatten())
a_hdi_gamma_4 = az.hdi(abcsmc_gamma_4.flatten())

a_beta_mean_4 = az.mean(abcsmc_beta_4, round_to=4)
a_gamma_mean_4 = az.mean(abcsmc_gamma_4, round_to=4)

# Test 5
a_hdi_beta_5 = az.hdi(abcsmc_beta_5.flatten())
a_hdi_gamma_5 = az.hdi(abcsmc_gamma_5.flatten())

a_beta_mean_5 = az.mean(abcsmc_beta_5, round_to=4)
a_gamma_mean_5 = az.mean(abcsmc_gamma_5, round_to=4)

# Test 6
a_hdi_beta_6 = az.hdi(abcsmc_beta_6.flatten())
a_hdi_gamma_6 = az.hdi(abcsmc_gamma_6.flatten())

a_beta_mean_6 = az.mean(abcsmc_beta_6, round_to=4)
a_gamma_mean_6 = az.mean(abcsmc_gamma_6, round_to=4)

# Test 7
a_hdi_beta_7 = az.hdi(abcsmc_beta_7.flatten())
a_hdi_gamma_7 = az.hdi(abcsmc_gamma_7.flatten())

a_beta_mean_7 = az.mean(abcsmc_beta_7, round_to=4)
a_gamma_mean_7 = az.mean(abcsmc_gamma_7, round_to=4)

# Test 8
a_hdi_beta_8 = az.hdi(abcsmc_beta_8.flatten())
a_hdi_gamma_8 = az.hdi(abcsmc_gamma_8.flatten())

a_beta_mean_8 = az.mean(abcsmc_beta_8, round_to=4)
a_gamma_mean_8 = az.mean(abcsmc_gamma_8, round_to=4)

# Test 9
a_hdi_beta_9 = az.hdi(abcsmc_beta_9.flatten())
a_hdi_gamma_9 = az.hdi(abcsmc_gamma_9.flatten())

a_beta_mean_9 = az.mean(abcsmc_beta_9, round_to=4)
a_gamma_mean_9 = az.mean(abcsmc_gamma_9, round_to=4)

# Test 10
a_hdi_beta_10 = az.hdi(abcsmc_beta_10.flatten())
a_hdi_gamma_10 = az.hdi(abcsmc_gamma_10.flatten())

a_beta_mean_10 = az.mean(abcsmc_beta_10, round_to=4)
a_gamma_mean_10 = az.mean(abcsmc_gamma_10, round_to=4)

# %%
true_beta = 0.45
true_gamma = 0.08

# %%
# TRANSMISSION RATE (Beta)
fig, axes = plt.subplots(8,2)

# PMMH
sb.kdeplot(pmmh_beta_1_1, ax=axes[0][0], label = 'Run 1').set_title(rf'$\rho$ = 0.50 $\phi$ = 5')
sb.kdeplot(pmmh_beta_1_2, ax=axes[0][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_1_3, ax=axes[0][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_1_4, ax=axes[0][0], label = 'Run 4')

axes[0][0].axvspan(hdi_beta_1[0], hdi_beta_1[1], alpha=0.1, color='red')
axes[0][0].axvline(hdi_beta_1[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_1[0]:.4f}, {hdi_beta_1[1]:.4f}]')
axes[0][0].axvline(hdi_beta_1[1], color='red', linestyle='--')

axes[0][0].axvline(x = beta_mean_1, color='black', label = rf'$\beta$ mean = {beta_mean_1} (error = {round(beta_mean_1 - true_beta,4)})')

"""sb.kdeplot(pmmh_beta_2_1, ax=axes[1][0], label = 'Run 1').set_title(rf'$\beta$ mean = {beta_mean_2}')
sb.kdeplot(pmmh_beta_2_2, ax=axes[1][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_2_3, ax=axes[1][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_2_4, ax=axes[1][0], label = 'Run 4')

axes[1][0].axvspan(hdi_beta_2[0], hdi_beta_2[1], alpha=0.1, color='red')
axes[1][0].axvline(hdi_beta_2[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_2[0]:.4f}, {hdi_beta_2[1]:.4f}]')
axes[1][0].axvline(hdi_beta_2[1], color='red', linestyle='--')"""

sb.kdeplot(pmmh_beta_3_1, ax=axes[1][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(pmmh_beta_3_2, ax=axes[1][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_3_3, ax=axes[1][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_3_4, ax=axes[1][0], label = 'Run 4')

axes[1][0].axvspan(hdi_beta_3[0], hdi_beta_3[1], alpha=0.1, color='red')
axes[1][0].axvline(hdi_beta_3[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_3[0]:.4f}, {hdi_beta_3[1]:.4f}]')
axes[1][0].axvline(hdi_beta_3[1], color='red', linestyle='--')

axes[1][0].axvline(x = beta_mean_3, color='black', label = rf'$\beta$ mean = {beta_mean_3} (error = {round(beta_mean_3 - true_beta,4)})')

sb.kdeplot(pmmh_beta_4_1, ax=axes[2][0], label = 'Run 1').set_title(rf'$\rho$ = 0.10 $\phi$ = 5')
sb.kdeplot(pmmh_beta_4_2, ax=axes[2][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_4_3, ax=axes[2][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_4_4, ax=axes[2][0], label = 'Run 4')

axes[2][0].axvspan(hdi_beta_4[0], hdi_beta_4[1], alpha=0.1, color='red')
axes[2][0].axvline(hdi_beta_4[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_4[0]:.4f}, {hdi_beta_4[1]:.4f}]')
axes[2][0].axvline(hdi_beta_4[1], color='red', linestyle='--')

axes[2][0].axvline(x = beta_mean_4, color='black', label = rf'$\beta$ mean = {beta_mean_4} (error = {round(beta_mean_4 - true_beta,4)})')

"""sb.kdeplot(pmmh_beta_5_1, ax=axes[4][0], label = 'Run 1').set_title(rf'$\beta$ mean = {beta_mean_5}')
sb.kdeplot(pmmh_beta_5_2, ax=axes[4][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_5_3, ax=axes[4][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_5_4, ax=axes[4][0], label = 'Run 4')

axes[4][0].axvspan(hdi_beta_5[0], hdi_beta_5[1], alpha=0.1, color='red')
axes[4][0].axvline(hdi_beta_5[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_5[0]:.4f}, {hdi_beta_5[1]:.4f}]')
axes[4][0].axvline(hdi_beta_5[1], color='red', linestyle='--')"""

sb.kdeplot(pmmh_beta_6_1, ax=axes[3][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 100')
sb.kdeplot(pmmh_beta_6_2, ax=axes[3][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_6_3, ax=axes[3][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_6_4, ax=axes[3][0], label = 'Run 4')

axes[3][0].axvspan(hdi_beta_6[0], hdi_beta_6[1], alpha=0.1, color='red')
axes[3][0].axvline(hdi_beta_6[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_6[0]:.4f}, {hdi_beta_6[1]:.4f}]')
axes[3][0].axvline(hdi_beta_6[1], color='red', linestyle='--')

axes[3][0].axvline(x = beta_mean_6, color='black', label = rf'$\beta$ mean = {beta_mean_6} (error = {round(beta_mean_6 - true_beta,4)})')

sb.kdeplot(pmmh_beta_7_1, ax=axes[4][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 50')
sb.kdeplot(pmmh_beta_7_2, ax=axes[4][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_7_3, ax=axes[4][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_7_4, ax=axes[4][0], label = 'Run 4')

axes[4][0].axvspan(hdi_beta_7[0], hdi_beta_7[1], alpha=0.1, color='red')
axes[4][0].axvline(hdi_beta_7[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_7[0]:.4f}, {hdi_beta_7[1]:.4f}]')
axes[4][0].axvline(hdi_beta_7[1], color='red', linestyle='--')

axes[4][0].axvline(x = beta_mean_7, color='black', label = rf'$\beta$ mean = {beta_mean_7} (error = {round(beta_mean_7 - true_beta,4)})')

sb.kdeplot(pmmh_beta_8_1, ax=axes[5][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 10')
sb.kdeplot(pmmh_beta_8_2, ax=axes[5][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_8_3, ax=axes[5][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_8_4, ax=axes[5][0], label = 'Run 4')

axes[5][0].axvspan(hdi_beta_8[0], hdi_beta_8[1], alpha=0.1, color='red')
axes[5][0].axvline(hdi_beta_8[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_8[0]:.4f}, {hdi_beta_8[1]:.4f}]')
axes[5][0].axvline(hdi_beta_8[1], color='red', linestyle='--')

axes[5][0].axvline(x = beta_mean_8, color='black', label = rf'$\beta$ mean = {beta_mean_8} (error = {round(beta_mean_8 - true_beta,4)})')

sb.kdeplot(pmmh_beta_9_1, ax=axes[6][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(pmmh_beta_9_2, ax=axes[6][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_9_3, ax=axes[6][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_9_4, ax=axes[6][0], label = 'Run 4')

axes[6][0].axvspan(hdi_beta_9[0], hdi_beta_9[1], alpha=0.1, color='red')
axes[6][0].axvline(hdi_beta_9[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_9[0]:.4f}, {hdi_beta_9[1]:.4f}]')
axes[6][0].axvline(hdi_beta_9[1], color='red', linestyle='--')

axes[6][0].axvline(x = beta_mean_9, color='black', label = rf'$\beta$ mean = {beta_mean_9} (error = {round(beta_mean_9 - true_beta,4)})')

sb.kdeplot(pmmh_beta_10_1, ax=axes[7][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 1')
sb.kdeplot(pmmh_beta_10_2, ax=axes[7][0], label = 'Run 2')
sb.kdeplot(pmmh_beta_10_3, ax=axes[7][0], label = 'Run 3')
sb.kdeplot(pmmh_beta_10_4, ax=axes[7][0], label = 'Run 4')

axes[7][0].axvspan(hdi_beta_10[0], hdi_beta_10[1], alpha=0.1, color='red')
axes[7][0].axvline(hdi_beta_10[0], color='red', linestyle='--', label = f'95% HDI [{hdi_beta_10[0]:.4f}, {hdi_beta_10[1]:.4f}]')
axes[7][0].axvline(hdi_beta_10[1], color='red', linestyle='--')

axes[7][0].axvline(x = beta_mean_10, color='black', label = rf'$\beta$ mean = {beta_mean_10} (error = {round(beta_mean_10 - true_beta,4)})')

# ABC-SMC
sb.kdeplot(abcsmc_beta_1_1, ax=axes[0][1], label = 'Run 1').set_title(rf'$\rho$ = 0.50 $\phi$ = 5')
sb.kdeplot(abcsmc_beta_1_2, ax=axes[0][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_1_3, ax=axes[0][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_1_4, ax=axes[0][1], label = 'Run 4')

axes[0][1].axvspan(a_hdi_beta_1[0], a_hdi_beta_1[1], alpha=0.1, color='red')
axes[0][1].axvline(a_hdi_beta_1[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_1[0]:.4f}, {a_hdi_beta_1[1]:.4f}]')
axes[0][1].axvline(a_hdi_beta_1[1], color='red', linestyle='--')

axes[0][1].axvline(x = a_beta_mean_1, color='black', label = rf'$\beta$ mean = {a_beta_mean_1} (error = {round(a_beta_mean_1 - true_beta,4)})')

"""sb.kdeplot(abcsmc_beta_2_1, ax=axes[1][1], label = 'Run 1').set_title(rf'$\beta$ mean = {a_beta_mean_2} (error = {round(a_beta_mean_2 - true_beta,4)})')
sb.kdeplot(abcsmc_beta_2_2, ax=axes[1][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_2_3, ax=axes[1][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_2_4, ax=axes[1][1], label = 'Run 4')

axes[1][1].axvspan(a_hdi_beta_2[0], a_hdi_beta_2[1], alpha=0.1, color='red')
axes[1][1].axvline(a_hdi_beta_2[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_2[0]:.4f}, {a_hdi_beta_2[1]:.4f}]')
axes[1][1].axvline(a_hdi_beta_2[1], color='red', linestyle='--')"""

sb.kdeplot(abcsmc_beta_3_1, ax=axes[1][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(abcsmc_beta_3_2, ax=axes[1][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_3_3, ax=axes[1][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_3_4, ax=axes[1][1], label = 'Run 4')

axes[1][1].axvspan(a_hdi_beta_3[0], a_hdi_beta_3[1], alpha=0.1, color='red')
axes[1][1].axvline(a_hdi_beta_3[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_3[0]:.4f}, {a_hdi_beta_3[1]:.4f}]')
axes[1][1].axvline(a_hdi_beta_3[1], color='red', linestyle='--')

axes[1][1].axvline(x = a_beta_mean_3, color='black', label = rf'$\beta$ mean = {a_beta_mean_3} (error = {round(a_beta_mean_3 - true_beta,4)})')

sb.kdeplot(abcsmc_beta_4_1, ax=axes[2][1], label = 'Run 1').set_title(rf'$\rho$ = 0.10 $\phi$ = 5')
sb.kdeplot(abcsmc_beta_4_2, ax=axes[2][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_4_3, ax=axes[2][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_4_4, ax=axes[2][1], label = 'Run 4')

axes[2][1].axvspan(a_hdi_beta_4[0], a_hdi_beta_4[1], alpha=0.1, color='red')
axes[2][1].axvline(a_hdi_beta_4[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_4[0]:.4f}, {a_hdi_beta_4[1]:.4f}]')
axes[2][1].axvline(a_hdi_beta_4[1], color='red', linestyle='--')

axes[2][1].axvline(x = a_beta_mean_4, color='black', label = rf'$\beta$ mean = {a_beta_mean_4} (error = {round(a_beta_mean_4 - true_beta,4)})')

"""sb.kdeplot(abcsmc_beta_5_1, ax=axes[4][1], label = 'Run 1').set_title(rf'$\beta$ mean = {a_beta_mean_5} (error = {round(a_beta_mean_5 - true_beta,4)})')
sb.kdeplot(abcsmc_beta_5_2, ax=axes[4][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_5_3, ax=axes[4][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_5_4, ax=axes[4][1], label = 'Run 4')

axes[4][1].axvspan(a_hdi_beta_5[0], a_hdi_beta_5[1], alpha=0.1, color='red')
axes[4][1].axvline(a_hdi_beta_5[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_5[0]:.4f}, {a_hdi_beta_5[1]:.4f}]')
axes[4][1].axvline(a_hdi_beta_5[1], color='red', linestyle='--')"""

sb.kdeplot(abcsmc_beta_6_1, ax=axes[3][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 100')
sb.kdeplot(abcsmc_beta_6_2, ax=axes[3][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_6_3, ax=axes[3][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_6_4, ax=axes[3][1], label = 'Run 4')

axes[3][1].axvspan(a_hdi_beta_6[0], a_hdi_beta_6[1], alpha=0.1, color='red')
axes[3][1].axvline(a_hdi_beta_6[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_6[0]:.4f}, {a_hdi_beta_6[1]:.4f}]')
axes[3][1].axvline(a_hdi_beta_6[1], color='red', linestyle='--')

axes[3][1].axvline(x = a_beta_mean_6, color='black', label = rf'$\beta$ mean = {a_beta_mean_6} (error = {round(a_beta_mean_6 - true_beta,4)})')

sb.kdeplot(abcsmc_beta_7_1, ax=axes[4][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 50')
sb.kdeplot(abcsmc_beta_7_2, ax=axes[4][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_7_3, ax=axes[4][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_7_4, ax=axes[4][1], label = 'Run 4')

axes[4][1].axvspan(a_hdi_beta_7[0], a_hdi_beta_7[1], alpha=0.1, color='red')
axes[4][1].axvline(a_hdi_beta_7[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_7[0]:.4f}, {a_hdi_beta_7[1]:.4f}]')
axes[4][1].axvline(a_hdi_beta_7[1], color='red', linestyle='--')

axes[4][1].axvline(x = a_beta_mean_7, color='black', label = rf'$\beta$ mean = {a_beta_mean_7} (error = {round(a_beta_mean_7 - true_beta,4)})')

sb.kdeplot(abcsmc_beta_8_1, ax=axes[5][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 10')
sb.kdeplot(abcsmc_beta_8_2, ax=axes[5][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_8_3, ax=axes[5][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_8_4, ax=axes[5][1], label = 'Run 4')

axes[5][1].axvspan(a_hdi_beta_8[0], a_hdi_beta_8[1], alpha=0.1, color='red')
axes[5][1].axvline(a_hdi_beta_8[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_8[0]:.4f}, {a_hdi_beta_8[1]:.4f}]')
axes[5][1].axvline(a_hdi_beta_8[1], color='red', linestyle='--')

axes[5][1].axvline(x = a_beta_mean_8, color='black', label = rf'$\beta$ mean = {a_beta_mean_8} (error = {round(a_beta_mean_8 - true_beta,4)})')

sb.kdeplot(abcsmc_beta_9_1, ax=axes[6][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(abcsmc_beta_9_2, ax=axes[6][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_9_3, ax=axes[6][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_9_4, ax=axes[6][1], label = 'Run 4')

axes[6][1].axvspan(a_hdi_beta_9[0], a_hdi_beta_9[1], alpha=0.1, color='red')
axes[6][1].axvline(a_hdi_beta_9[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_9[0]:.4f}, {a_hdi_beta_9[1]:.4f}]')
axes[6][1].axvline(a_hdi_beta_9[1], color='red', linestyle='--')

axes[6][1].axvline(x = a_beta_mean_9, color='black', label = rf'$\beta$ mean = {a_beta_mean_9} (error = {round(a_beta_mean_9 - true_beta,4)})')

sb.kdeplot(abcsmc_beta_10_1, ax=axes[7][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 1')
sb.kdeplot(abcsmc_beta_10_2, ax=axes[7][1], label = 'Run 2')
sb.kdeplot(abcsmc_beta_10_3, ax=axes[7][1], label = 'Run 3')
sb.kdeplot(abcsmc_beta_10_4, ax=axes[7][1], label = 'Run 4')

axes[7][1].axvspan(a_hdi_beta_10[0], a_hdi_beta_10[1], alpha=0.1, color='red')
axes[7][1].axvline(a_hdi_beta_10[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_beta_10[0]:.4f}, {a_hdi_beta_10[1]:.4f}]')
axes[7][1].axvline(a_hdi_beta_10[1], color='red', linestyle='--')

axes[7][1].axvline(x = a_beta_mean_10, color='black', label = rf'$\beta$ mean = {a_beta_mean_10} (error = {round(a_beta_mean_10 - true_beta,4)})')

#axes[1].axvline(x = 0.1071, color='black')


plt.setp(axes, xlim=(0.25, 0.75), ylim=(0, 16))


axes[0][0].legend()
axes[0][1].legend()
axes[1][0].legend()
axes[1][1].legend()
axes[2][0].legend()
axes[2][1].legend()
axes[3][0].legend()
axes[3][1].legend()
axes[4][0].legend()
axes[4][1].legend()
axes[5][0].legend()
axes[5][1].legend()
axes[6][0].legend()
axes[6][1].legend()
axes[7][0].legend()
axes[7][1].legend()
"""axes[8][0].legend()
axes[8][1].legend()
axes[9][0].legend()
axes[9][1].legend()"""




axes[7][0].set_xlabel('PMMH')
axes[7][1].set_xlabel('ABC-SMC')


plt.subplots_adjust(wspace=0.1, hspace=0.3)

fig.set_figheight(25)
fig.set_figwidth(20)

# %%
# TRANSMISSION RATE (gamma)
fig, axes = plt.subplots(8,2)

# PMMH
sb.kdeplot(pmmh_gamma_1_1, ax=axes[0][0], label = 'Run 1').set_title(rf'$\rho$ = 0.50 $\phi$ = 5')
sb.kdeplot(pmmh_gamma_1_2, ax=axes[0][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_1_3, ax=axes[0][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_1_4, ax=axes[0][0], label = 'Run 4')

axes[0][0].axvspan(hdi_gamma_1[0], hdi_gamma_1[1], alpha=0.1, color='red')
axes[0][0].axvline(hdi_gamma_1[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_1[0]:.4f}, {hdi_gamma_1[1]:.4f}]')
axes[0][0].axvline(hdi_gamma_1[1], color='red', linestyle='--')

axes[0][0].axvline(x = gamma_mean_1, color='black', label = rf'$\gamma$ mean = {gamma_mean_1} (error = {round(gamma_mean_1 - true_gamma,4)})')

"""sb.kdeplot(pmmh_gamma_2_1, ax=axes[1][0], label = 'Run 1').set_title(rf'$\gamma$ mean = {gamma_mean_2}')
sb.kdeplot(pmmh_gamma_2_2, ax=axes[1][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_2_3, ax=axes[1][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_2_4, ax=axes[1][0], label = 'Run 4')

axes[1][0].axvspan(hdi_gamma_2[0], hdi_gamma_2[1], alpha=0.1, color='red')
axes[1][0].axvline(hdi_gamma_2[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_2[0]:.4f}, {hdi_gamma_2[1]:.4f}]')
axes[1][0].axvline(hdi_gamma_2[1], color='red', linestyle='--')"""

sb.kdeplot(pmmh_gamma_3_1, ax=axes[1][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(pmmh_gamma_3_2, ax=axes[1][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_3_3, ax=axes[1][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_3_4, ax=axes[1][0], label = 'Run 4')

axes[1][0].axvspan(hdi_gamma_3[0], hdi_gamma_3[1], alpha=0.1, color='red')
axes[1][0].axvline(hdi_gamma_3[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_3[0]:.4f}, {hdi_gamma_3[1]:.4f}]')
axes[1][0].axvline(hdi_gamma_3[1], color='red', linestyle='--')

axes[1][0].axvline(x = gamma_mean_3, color='black', label = rf'$\gamma$ mean = {gamma_mean_3} (error = {round(gamma_mean_3 - true_gamma,4)})')

sb.kdeplot(pmmh_gamma_4_1, ax=axes[2][0], label = 'Run 1').set_title(rf'$\rho$ = 0.10 $\phi$ = 5')
sb.kdeplot(pmmh_gamma_4_2, ax=axes[2][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_4_3, ax=axes[2][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_4_4, ax=axes[2][0], label = 'Run 4')

axes[2][0].axvspan(hdi_gamma_4[0], hdi_gamma_4[1], alpha=0.1, color='red')
axes[2][0].axvline(hdi_gamma_4[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_4[0]:.4f}, {hdi_gamma_4[1]:.4f}]')
axes[2][0].axvline(hdi_gamma_4[1], color='red', linestyle='--')

axes[2][0].axvline(x = gamma_mean_4, color='black', label = rf'$\gamma$ mean = {gamma_mean_4} (error = {round(gamma_mean_4 - true_gamma,4)})')

"""sb.kdeplot(pmmh_gamma_5_1, ax=axes[4][0], label = 'Run 1').set_title(rf'$\gamma$ mean = {gamma_mean_5}')
sb.kdeplot(pmmh_gamma_5_2, ax=axes[4][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_5_3, ax=axes[4][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_5_4, ax=axes[4][0], label = 'Run 4')

axes[4][0].axvspan(hdi_gamma_5[0], hdi_gamma_5[1], alpha=0.1, color='red')
axes[4][0].axvline(hdi_gamma_5[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_5[0]:.4f}, {hdi_gamma_5[1]:.4f}]')
axes[4][0].axvline(hdi_gamma_5[1], color='red', linestyle='--')"""

sb.kdeplot(pmmh_gamma_6_1, ax=axes[3][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 100')
sb.kdeplot(pmmh_gamma_6_2, ax=axes[3][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_6_3, ax=axes[3][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_6_4, ax=axes[3][0], label = 'Run 4')

axes[3][0].axvspan(hdi_gamma_6[0], hdi_gamma_6[1], alpha=0.1, color='red')
axes[3][0].axvline(hdi_gamma_6[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_6[0]:.4f}, {hdi_gamma_6[1]:.4f}]')
axes[3][0].axvline(hdi_gamma_6[1], color='red', linestyle='--')

axes[3][0].axvline(x = gamma_mean_6, color='black', label = rf'$\gamma$ mean = {gamma_mean_6} (error = {round(gamma_mean_6 - true_gamma,4)})')

sb.kdeplot(pmmh_gamma_7_1, ax=axes[4][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 50')
sb.kdeplot(pmmh_gamma_7_2, ax=axes[4][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_7_3, ax=axes[4][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_7_4, ax=axes[4][0], label = 'Run 4')

axes[4][0].axvspan(hdi_gamma_7[0], hdi_gamma_7[1], alpha=0.1, color='red')
axes[4][0].axvline(hdi_gamma_7[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_7[0]:.4f}, {hdi_gamma_7[1]:.4f}]')
axes[4][0].axvline(hdi_gamma_7[1], color='red', linestyle='--')

axes[4][0].axvline(x = gamma_mean_7, color='black', label = rf'$\gamma$ mean = {gamma_mean_7} (error = {round(gamma_mean_7 - true_gamma,4)})')

sb.kdeplot(pmmh_gamma_8_1, ax=axes[5][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 10')
sb.kdeplot(pmmh_gamma_8_2, ax=axes[5][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_8_3, ax=axes[5][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_8_4, ax=axes[5][0], label = 'Run 4')

axes[5][0].axvspan(hdi_gamma_8[0], hdi_gamma_8[1], alpha=0.1, color='red')
axes[5][0].axvline(hdi_gamma_8[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_8[0]:.4f}, {hdi_gamma_8[1]:.4f}]')
axes[5][0].axvline(hdi_gamma_8[1], color='red', linestyle='--')

axes[5][0].axvline(x = gamma_mean_8, color='black', label = rf'$\gamma$ mean = {gamma_mean_8} (error = {round(gamma_mean_8 - true_gamma,4)})')

sb.kdeplot(pmmh_gamma_9_1, ax=axes[6][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(pmmh_gamma_9_2, ax=axes[6][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_9_3, ax=axes[6][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_9_4, ax=axes[6][0], label = 'Run 4')

axes[6][0].axvspan(hdi_gamma_9[0], hdi_gamma_9[1], alpha=0.1, color='red')
axes[6][0].axvline(hdi_gamma_9[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_9[0]:.4f}, {hdi_gamma_9[1]:.4f}]')
axes[6][0].axvline(hdi_gamma_9[1], color='red', linestyle='--')

axes[6][0].axvline(x = gamma_mean_9, color='black', label = rf'$\gamma$ mean = {gamma_mean_9} (error = {round(gamma_mean_9 - true_gamma,4)})')

sb.kdeplot(pmmh_gamma_10_1, ax=axes[7][0], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 1')
sb.kdeplot(pmmh_gamma_10_2, ax=axes[7][0], label = 'Run 2')
sb.kdeplot(pmmh_gamma_10_3, ax=axes[7][0], label = 'Run 3')
sb.kdeplot(pmmh_gamma_10_4, ax=axes[7][0], label = 'Run 4')

axes[7][0].axvspan(hdi_gamma_10[0], hdi_gamma_10[1], alpha=0.1, color='red')
axes[7][0].axvline(hdi_gamma_10[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_10[0]:.4f}, {hdi_gamma_10[1]:.4f}]')
axes[7][0].axvline(hdi_gamma_10[1], color='red', linestyle='--')

axes[7][0].axvline(x = gamma_mean_10, color='black', label = rf'$\gamma$ mean = {gamma_mean_10} (error = {round(gamma_mean_10 - true_gamma,4)})')

# ABC-SMC
sb.kdeplot(abcsmc_gamma_1_1, ax=axes[0][1], label = 'Run 1').set_title(rf'$\rho$ = 0.50 $\phi$ = 5')
sb.kdeplot(abcsmc_gamma_1_2, ax=axes[0][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_1_3, ax=axes[0][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_1_4, ax=axes[0][1], label = 'Run 4')

axes[0][1].axvspan(a_hdi_gamma_1[0], a_hdi_gamma_1[1], alpha=0.1, color='red')
axes[0][1].axvline(a_hdi_gamma_1[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_1[0]:.4f}, {a_hdi_gamma_1[1]:.4f}]')
axes[0][1].axvline(a_hdi_gamma_1[1], color='red', linestyle='--')

axes[0][1].axvline(x = a_gamma_mean_1, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_1} (error = {round(a_gamma_mean_1 - true_gamma,4)})')

"""sb.kdeplot(abcsmc_gamma_2_1, ax=axes[1][1], label = 'Run 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_2} (error = {round(a_gamma_mean_2 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_2_2, ax=axes[1][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_2_3, ax=axes[1][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_2_4, ax=axes[1][1], label = 'Run 4')

axes[1][1].axvspan(a_hdi_gamma_2[0], a_hdi_gamma_2[1], alpha=0.1, color='red')
axes[1][1].axvline(a_hdi_gamma_2[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_2[0]:.4f}, {a_hdi_gamma_2[1]:.4f}]')
axes[1][1].axvline(a_hdi_gamma_2[1], color='red', linestyle='--')"""

sb.kdeplot(abcsmc_gamma_3_1, ax=axes[1][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(abcsmc_gamma_3_2, ax=axes[1][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_3_3, ax=axes[1][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_3_4, ax=axes[1][1], label = 'Run 4')

axes[1][1].axvspan(a_hdi_gamma_3[0], a_hdi_gamma_3[1], alpha=0.1, color='red')
axes[1][1].axvline(a_hdi_gamma_3[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_3[0]:.4f}, {a_hdi_gamma_3[1]:.4f}]')
axes[1][1].axvline(a_hdi_gamma_3[1], color='red', linestyle='--')

axes[1][1].axvline(x = a_gamma_mean_3, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_3} (error = {round(a_gamma_mean_3 - true_gamma,4)})')

sb.kdeplot(abcsmc_gamma_4_1, ax=axes[2][1], label = 'Run 1').set_title(rf'$\rho$ = 0.10 $\phi$ = 5')
sb.kdeplot(abcsmc_gamma_4_2, ax=axes[2][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_4_3, ax=axes[2][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_4_4, ax=axes[2][1], label = 'Run 4')

axes[2][1].axvspan(a_hdi_gamma_4[0], a_hdi_gamma_4[1], alpha=0.1, color='red')
axes[2][1].axvline(a_hdi_gamma_4[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_4[0]:.4f}, {a_hdi_gamma_4[1]:.4f}]')
axes[2][1].axvline(a_hdi_gamma_4[1], color='red', linestyle='--')

axes[2][1].axvline(x = a_gamma_mean_4, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_4} (error = {round(a_gamma_mean_4 - true_gamma,4)})')

"""sb.kdeplot(abcsmc_gamma_5_1, ax=axes[4][1], label = 'Run 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_5} (error = {round(a_gamma_mean_5 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_5_2, ax=axes[4][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_5_3, ax=axes[4][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_5_4, ax=axes[4][1], label = 'Run 4')

axes[4][1].axvspan(a_hdi_gamma_5[0], a_hdi_gamma_5[1], alpha=0.1, color='red')
axes[4][1].axvline(a_hdi_gamma_5[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_5[0]:.4f}, {a_hdi_gamma_5[1]:.4f}]')
axes[4][1].axvline(a_hdi_gamma_5[1], color='red', linestyle='--')"""

sb.kdeplot(abcsmc_gamma_6_1, ax=axes[3][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 100')
sb.kdeplot(abcsmc_gamma_6_2, ax=axes[3][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_6_3, ax=axes[3][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_6_4, ax=axes[3][1], label = 'Run 4')

axes[3][1].axvspan(a_hdi_gamma_6[0], a_hdi_gamma_6[1], alpha=0.1, color='red')
axes[3][1].axvline(a_hdi_gamma_6[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_6[0]:.4f}, {a_hdi_gamma_6[1]:.4f}]')
axes[3][1].axvline(a_hdi_gamma_6[1], color='red', linestyle='--')

axes[3][1].axvline(x = a_gamma_mean_6, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_6} (error = {round(a_gamma_mean_6 - true_gamma,4)})')

sb.kdeplot(abcsmc_gamma_7_1, ax=axes[4][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 50')
sb.kdeplot(abcsmc_gamma_7_2, ax=axes[4][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_7_3, ax=axes[4][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_7_4, ax=axes[4][1], label = 'Run 4')

axes[4][1].axvspan(a_hdi_gamma_7[0], a_hdi_gamma_7[1], alpha=0.1, color='red')
axes[4][1].axvline(a_hdi_gamma_7[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_7[0]:.4f}, {a_hdi_gamma_7[1]:.4f}]')
axes[4][1].axvline(a_hdi_gamma_7[1], color='red', linestyle='--')

axes[4][1].axvline(x = a_gamma_mean_7, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_7} (error = {round(a_gamma_mean_7 - true_gamma,4)})')

sb.kdeplot(abcsmc_gamma_8_1, ax=axes[5][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 10')
sb.kdeplot(abcsmc_gamma_8_2, ax=axes[5][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_8_3, ax=axes[5][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_8_4, ax=axes[5][1], label = 'Run 4')

axes[5][1].axvspan(a_hdi_gamma_8[0], a_hdi_gamma_8[1], alpha=0.1, color='red')
axes[5][1].axvline(a_hdi_gamma_8[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_8[0]:.4f}, {a_hdi_gamma_8[1]:.4f}]')
axes[5][1].axvline(a_hdi_gamma_8[1], color='red', linestyle='--')

axes[5][1].axvline(x = a_gamma_mean_8, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_8} (error = {round(a_gamma_mean_8 - true_gamma,4)})')

sb.kdeplot(abcsmc_gamma_9_1, ax=axes[6][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 5')
sb.kdeplot(abcsmc_gamma_9_2, ax=axes[6][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_9_3, ax=axes[6][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_9_4, ax=axes[6][1], label = 'Run 4')

axes[6][1].axvspan(a_hdi_gamma_9[0], a_hdi_gamma_9[1], alpha=0.1, color='red')
axes[6][1].axvline(a_hdi_gamma_9[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_9[0]:.4f}, {a_hdi_gamma_9[1]:.4f}]')
axes[6][1].axvline(a_hdi_gamma_9[1], color='red', linestyle='--')

axes[6][1].axvline(x = a_gamma_mean_9, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_9} (error = {round(a_gamma_mean_9 - true_gamma,4)})')

sb.kdeplot(abcsmc_gamma_10_1, ax=axes[7][1], label = 'Run 1').set_title(rf'$\rho$ = 0.25 $\phi$ = 1')
sb.kdeplot(abcsmc_gamma_10_2, ax=axes[7][1], label = 'Run 2')
sb.kdeplot(abcsmc_gamma_10_3, ax=axes[7][1], label = 'Run 3')
sb.kdeplot(abcsmc_gamma_10_4, ax=axes[7][1], label = 'Run 4')

axes[7][1].axvspan(a_hdi_gamma_10[0], a_hdi_gamma_10[1], alpha=0.1, color='red')
axes[7][1].axvline(a_hdi_gamma_10[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_10[0]:.4f}, {a_hdi_gamma_10[1]:.4f}]')
axes[7][1].axvline(a_hdi_gamma_10[1], color='red', linestyle='--')

axes[7][1].axvline(x = a_gamma_mean_10, color='black', label = rf'$\gamma$ mean = {a_gamma_mean_10} (error = {round(a_gamma_mean_10 - true_gamma,4)})')

#axes[1].axvline(x = 0.1071, color='black')


plt.setp(axes, xlim=(-0.1, 0.5), ylim=(0, 26))


axes[0][0].legend()
axes[0][1].legend()
axes[1][0].legend()
axes[1][1].legend()
axes[2][0].legend()
axes[2][1].legend()
axes[3][0].legend()
axes[3][1].legend()
axes[4][0].legend()
axes[4][1].legend()
axes[5][0].legend()
axes[5][1].legend()
axes[6][0].legend()
axes[6][1].legend()
axes[7][0].legend()
axes[7][1].legend()
"""axes[8][0].legend()
axes[8][1].legend()
axes[9][0].legend()
axes[9][1].legend()"""




axes[7][0].set_xlabel('PMMH')
axes[7][1].set_xlabel('ABC-SMC')


plt.subplots_adjust(wspace=0.1, hspace=0.3)

fig.set_figheight(35)
fig.set_figwidth(20)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\g'
# <>:47: SyntaxWarning: invalid escape sequence '\g'
# <>:123: SyntaxWarning: invalid escape sequence '\g'
# <>:154: SyntaxWarning: invalid escape sequence '\g'
# <>:16: SyntaxWarning: invalid escape sequence '\g'
# <>:47: SyntaxWarning: invalid escape sequence '\g'
# <>:123: SyntaxWarning: invalid escape sequence '\g'
# <>:154: SyntaxWarning: invalid escape sequence '\g'
# /var/folders/78/7v9nz15x7059dykx93846qzm0000gn/T/ipykernel_4046/3389924387.py:16: SyntaxWarning: invalid escape sequence '\g'
#   """sb.kdeplot(pmmh_gamma_2_1, ax=axes[1][0], label = 'Run 1').set_title(rf'$\gamma$ mean = {gamma_mean_2}')
# /var/folders/78/7v9nz15x7059dykx93846qzm0000gn/T/ipykernel_4046/3389924387.py:47: SyntaxWarning: invalid escape sequence '\g'
#   """sb.kdeplot(pmmh_gamma_5_1, ax=axes[4][0], label = 'Run 1').set_title(rf'$\gamma$ mean = {gamma_mean_5}')
# ...

# %%
# TRANSMISSION RATE (gamma)
fig, axes = plt.subplots(8,2)

# PMMH
sb.kdeplot(pmmh_gamma_1_1, ax=axes[0][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_1} (Error = {round(gamma_mean_1 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_1_2, ax=axes[0][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_1_3, ax=axes[0][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_1_4, ax=axes[0][0], label = 'ABC-SMC Chain 4')

axes[0][0].axvspan(hdi_gamma_1[0], hdi_gamma_1[1], alpha=0.1, color='red')
axes[0][0].axvline(hdi_gamma_1[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_1[0]:.3f}, {hdi_gamma_1[1]:.3f}]')
axes[0][0].axvline(hdi_gamma_1[1], color='red', linestyle='--')

"""sb.kdeplot(pmmh_gamma_2_1, ax=axes[1][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_2}')
sb.kdeplot(pmmh_gamma_2_2, ax=axes[1][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_2_3, ax=axes[1][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_2_4, ax=axes[1][0], label = 'ABC-SMC Chain 4')

axes[1][0].axvspan(hdi_gamma_2[0], hdi_gamma_2[1], alpha=0.1, color='red')
axes[1][0].axvline(hdi_gamma_2[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_2[0]:.3f}, {hdi_gamma_2[1]:.3f}]')
axes[1][0].axvline(hdi_gamma_2[1], color='red', linestyle='--')"""

sb.kdeplot(pmmh_gamma_3_1, ax=axes[1][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_3} (Error = {round(gamma_mean_3 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_3_2, ax=axes[1][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_3_3, ax=axes[1][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_3_4, ax=axes[1][0], label = 'ABC-SMC Chain 4')

axes[1][0].axvspan(hdi_gamma_3[0], hdi_gamma_3[1], alpha=0.1, color='red')
axes[1][0].axvline(hdi_gamma_3[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_3[0]:.3f}, {hdi_gamma_3[1]:.3f}]')
axes[1][0].axvline(hdi_gamma_3[1], color='red', linestyle='--')

sb.kdeplot(pmmh_gamma_4_1, ax=axes[2][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_4} (Error = {round(gamma_mean_4 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_4_2, ax=axes[2][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_4_3, ax=axes[2][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_4_4, ax=axes[2][0], label = 'ABC-SMC Chain 4')

axes[2][0].axvspan(hdi_gamma_4[0], hdi_gamma_4[1], alpha=0.1, color='red')
axes[2][0].axvline(hdi_gamma_4[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_4[0]:.3f}, {hdi_gamma_4[1]:.3f}]')
axes[2][0].axvline(hdi_gamma_4[1], color='red', linestyle='--')

"""sb.kdeplot(pmmh_gamma_5_1, ax=axes[4][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_5}')
sb.kdeplot(pmmh_gamma_5_2, ax=axes[4][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_5_3, ax=axes[4][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_5_4, ax=axes[4][0], label = 'ABC-SMC Chain 4')

axes[4][0].axvspan(hdi_gamma_5[0], hdi_gamma_5[1], alpha=0.1, color='red')
axes[4][0].axvline(hdi_gamma_5[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_5[0]:.3f}, {hdi_gamma_5[1]:.3f}]')
axes[4][0].axvline(hdi_gamma_5[1], color='red', linestyle='--')"""

sb.kdeplot(pmmh_gamma_6_1, ax=axes[3][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_6} (Error = {round(gamma_mean_6 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_6_2, ax=axes[3][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_6_3, ax=axes[3][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_6_4, ax=axes[3][0], label = 'ABC-SMC Chain 4')

axes[3][0].axvspan(hdi_gamma_6[0], hdi_gamma_6[1], alpha=0.1, color='red')
axes[3][0].axvline(hdi_gamma_6[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_6[0]:.3f}, {hdi_gamma_6[1]:.3f}]')
axes[3][0].axvline(hdi_gamma_6[1], color='red', linestyle='--')

sb.kdeplot(pmmh_gamma_7_1, ax=axes[4][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_7} (Error = {round(gamma_mean_7 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_7_2, ax=axes[4][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_7_3, ax=axes[4][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_7_4, ax=axes[4][0], label = 'ABC-SMC Chain 4')

axes[4][0].axvspan(hdi_gamma_7[0], hdi_gamma_7[1], alpha=0.1, color='red')
axes[4][0].axvline(hdi_gamma_7[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_7[0]:.3f}, {hdi_gamma_7[1]:.3f}]')
axes[4][0].axvline(hdi_gamma_7[1], color='red', linestyle='--')

sb.kdeplot(pmmh_gamma_8_1, ax=axes[5][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_8} (Error = {round(gamma_mean_8 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_8_2, ax=axes[5][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_8_3, ax=axes[5][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_8_4, ax=axes[5][0], label = 'ABC-SMC Chain 4')

axes[5][0].axvspan(hdi_gamma_8[0], hdi_gamma_8[1], alpha=0.1, color='red')
axes[5][0].axvline(hdi_gamma_8[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_8[0]:.3f}, {hdi_gamma_8[1]:.3f}]')
axes[5][0].axvline(hdi_gamma_8[1], color='red', linestyle='--')

sb.kdeplot(pmmh_gamma_9_1, ax=axes[6][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_9} (Error = {round(gamma_mean_9 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_9_2, ax=axes[6][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_9_3, ax=axes[6][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_9_4, ax=axes[6][0], label = 'ABC-SMC Chain 4')

axes[6][0].axvspan(hdi_gamma_9[0], hdi_gamma_9[1], alpha=0.1, color='red')
axes[6][0].axvline(hdi_gamma_9[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_9[0]:.3f}, {hdi_gamma_9[1]:.3f}]')
axes[6][0].axvline(hdi_gamma_9[1], color='red', linestyle='--')

sb.kdeplot(pmmh_gamma_10_1, ax=axes[7][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_10} (Error = {round(gamma_mean_10 - true_gamma,4)})')
sb.kdeplot(pmmh_gamma_10_2, ax=axes[7][0], label = 'ABC-SMC Chain 2')
sb.kdeplot(pmmh_gamma_10_3, ax=axes[7][0], label = 'ABC-SMC Chain 3')
sb.kdeplot(pmmh_gamma_10_4, ax=axes[7][0], label = 'ABC-SMC Chain 4')

axes[7][0].axvspan(hdi_gamma_10[0], hdi_gamma_10[1], alpha=0.1, color='red')
axes[7][0].axvline(hdi_gamma_10[0], color='red', linestyle='--', label = f'95% HDI [{hdi_gamma_10[0]:.3f}, {hdi_gamma_10[1]:.3f}]')
axes[7][0].axvline(hdi_gamma_10[1], color='red', linestyle='--')

# ABC-SMC
sb.kdeplot(abcsmc_gamma_1_1, ax=axes[0][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_1} (Error = {round(a_gamma_mean_1 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_1_2, ax=axes[0][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_1_3, ax=axes[0][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_1_4, ax=axes[0][1], label = 'ABC-SMC Chain 4')

axes[0][1].axvspan(a_hdi_gamma_1[0], a_hdi_gamma_1[1], alpha=0.1, color='red')
axes[0][1].axvline(a_hdi_gamma_1[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_1[0]:.3f}, {a_hdi_gamma_1[1]:.3f}]')
axes[0][1].axvline(a_hdi_gamma_1[1], color='red', linestyle='--')

"""sb.kdeplot(abcsmc_gamma_2_1, ax=axes[1][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_2} (Error = {round(a_gamma_mean_2 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_2_2, ax=axes[1][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_2_3, ax=axes[1][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_2_4, ax=axes[1][1], label = 'ABC-SMC Chain 4')

axes[1][1].axvspan(a_hdi_gamma_2[0], a_hdi_gamma_2[1], alpha=0.1, color='red')
axes[1][1].axvline(a_hdi_gamma_2[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_2[0]:.3f}, {a_hdi_gamma_2[1]:.3f}]')
axes[1][1].axvline(a_hdi_gamma_2[1], color='red', linestyle='--')"""

sb.kdeplot(abcsmc_gamma_3_1, ax=axes[1][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_3} (Error = {round(a_gamma_mean_3 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_3_2, ax=axes[1][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_3_3, ax=axes[1][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_3_4, ax=axes[1][1], label = 'ABC-SMC Chain 4')

axes[1][1].axvspan(a_hdi_gamma_3[0], a_hdi_gamma_3[1], alpha=0.1, color='red')
axes[1][1].axvline(a_hdi_gamma_3[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_3[0]:.3f}, {a_hdi_gamma_3[1]:.3f}]')
axes[1][1].axvline(a_hdi_gamma_3[1], color='red', linestyle='--')

sb.kdeplot(abcsmc_gamma_4_1, ax=axes[2][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_4} (Error = {round(a_gamma_mean_4 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_4_2, ax=axes[2][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_4_3, ax=axes[2][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_4_4, ax=axes[2][1], label = 'ABC-SMC Chain 4')

axes[2][1].axvspan(a_hdi_gamma_4[0], a_hdi_gamma_4[1], alpha=0.1, color='red')
axes[2][1].axvline(a_hdi_gamma_4[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_4[0]:.3f}, {a_hdi_gamma_4[1]:.3f}]')
axes[2][1].axvline(a_hdi_gamma_4[1], color='red', linestyle='--')

"""sb.kdeplot(abcsmc_gamma_5_1, ax=axes[4][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_5} (Error = {round(a_gamma_mean_5 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_5_2, ax=axes[4][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_5_3, ax=axes[4][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_5_4, ax=axes[4][1], label = 'ABC-SMC Chain 4')

axes[4][1].axvspan(a_hdi_gamma_5[0], a_hdi_gamma_5[1], alpha=0.1, color='red')
axes[4][1].axvline(a_hdi_gamma_5[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_5[0]:.3f}, {a_hdi_gamma_5[1]:.3f}]')
axes[4][1].axvline(a_hdi_gamma_5[1], color='red', linestyle='--')"""

sb.kdeplot(abcsmc_gamma_6_1, ax=axes[3][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_6} (Error = {round(a_gamma_mean_6 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_6_2, ax=axes[3][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_6_3, ax=axes[3][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_6_4, ax=axes[3][1], label = 'ABC-SMC Chain 4')

axes[3][1].axvspan(a_hdi_gamma_6[0], a_hdi_gamma_6[1], alpha=0.1, color='red')
axes[3][1].axvline(a_hdi_gamma_6[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_6[0]:.3f}, {a_hdi_gamma_6[1]:.3f}]')
axes[3][1].axvline(a_hdi_gamma_6[1], color='red', linestyle='--')

sb.kdeplot(abcsmc_gamma_7_1, ax=axes[4][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_7} (Error = {round(a_gamma_mean_7 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_7_2, ax=axes[4][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_7_3, ax=axes[4][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_7_4, ax=axes[4][1], label = 'ABC-SMC Chain 4')

axes[4][1].axvspan(a_hdi_gamma_7[0], a_hdi_gamma_7[1], alpha=0.1, color='red')
axes[4][1].axvline(a_hdi_gamma_7[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_7[0]:.3f}, {a_hdi_gamma_7[1]:.3f}]')
axes[4][1].axvline(a_hdi_gamma_7[1], color='red', linestyle='--')

sb.kdeplot(abcsmc_gamma_8_1, ax=axes[5][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_8} (Error = {round(a_gamma_mean_8 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_8_2, ax=axes[5][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_8_3, ax=axes[5][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_8_4, ax=axes[5][1], label = 'ABC-SMC Chain 4')

axes[5][1].axvspan(a_hdi_gamma_8[0], a_hdi_gamma_8[1], alpha=0.1, color='red')
axes[5][1].axvline(a_hdi_gamma_8[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_8[0]:.3f}, {a_hdi_gamma_8[1]:.3f}]')
axes[5][1].axvline(a_hdi_gamma_8[1], color='red', linestyle='--')

sb.kdeplot(abcsmc_gamma_9_1, ax=axes[6][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_9} (Error = {round(a_gamma_mean_9 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_9_2, ax=axes[6][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_9_3, ax=axes[6][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_9_4, ax=axes[6][1], label = 'ABC-SMC Chain 4')

axes[6][1].axvspan(a_hdi_gamma_9[0], a_hdi_gamma_9[1], alpha=0.1, color='red')
axes[6][1].axvline(a_hdi_gamma_9[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_9[0]:.3f}, {a_hdi_gamma_9[1]:.3f}]')
axes[6][1].axvline(a_hdi_gamma_9[1], color='red', linestyle='--')

sb.kdeplot(abcsmc_gamma_10_1, ax=axes[7][1], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {a_gamma_mean_10} (Error = {round(a_gamma_mean_10 - true_gamma,4)})')
sb.kdeplot(abcsmc_gamma_10_2, ax=axes[7][1], label = 'ABC-SMC Chain 2')
sb.kdeplot(abcsmc_gamma_10_3, ax=axes[7][1], label = 'ABC-SMC Chain 3')
sb.kdeplot(abcsmc_gamma_10_4, ax=axes[7][1], label = 'ABC-SMC Chain 4')

axes[7][1].axvspan(a_hdi_gamma_10[0], a_hdi_gamma_10[1], alpha=0.1, color='red')
axes[7][1].axvline(a_hdi_gamma_10[0], color='red', linestyle='--', label = f'95% HDI [{a_hdi_gamma_10[0]:.3f}, {a_hdi_gamma_10[1]:.3f}]')
axes[7][1].axvline(a_hdi_gamma_10[1], color='red', linestyle='--')

#axes[0].axvline(x = 0.4438, color='black')
#axes[0].hlines(y = 0.5, xmin = 0.3926, xmax = 0.4896, color='black')
#axes[1].axvline(x = 0.1071, color='black')
#axes[1].hlines(y = 0.5, xmin = 0.0646, xmax = 0.1521, color='black')

plt.setp(axes, xlim=(-0.1, 0.5), ylim=(0, 26))


axes[0][0].legend()
axes[0][1].legend()
axes[1][0].legend()
axes[1][1].legend()
axes[2][0].legend()
axes[2][1].legend()
axes[3][0].legend()
axes[3][1].legend()
axes[4][0].legend()
axes[4][1].legend()
axes[5][0].legend()
axes[5][1].legend()
axes[6][0].legend()
axes[6][1].legend()
axes[7][0].legend()
axes[7][1].legend()
"""axes[8][0].legend()
axes[8][1].legend()
axes[9][0].legend()
axes[9][1].legend()"""


axes[7][0].set_xlabel('PMMH')
axes[7][1].set_xlabel('ABC-SMC')




fig.set_figheight(40)
fig.set_figwidth(15)
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\g'
# <>:41: SyntaxWarning: invalid escape sequence '\g'
# <>:105: SyntaxWarning: invalid escape sequence '\g'
# <>:132: SyntaxWarning: invalid escape sequence '\g'
# <>:14: SyntaxWarning: invalid escape sequence '\g'
# <>:41: SyntaxWarning: invalid escape sequence '\g'
# <>:105: SyntaxWarning: invalid escape sequence '\g'
# <>:132: SyntaxWarning: invalid escape sequence '\g'
# /var/folders/78/7v9nz15x7059dykx93846qzm0000gn/T/ipykernel_4046/1300860601.py:14: SyntaxWarning: invalid escape sequence '\g'
#   """sb.kdeplot(pmmh_gamma_2_1, ax=axes[1][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_2}')
# /var/folders/78/7v9nz15x7059dykx93846qzm0000gn/T/ipykernel_4046/1300860601.py:41: SyntaxWarning: invalid escape sequence '\g'
#   """sb.kdeplot(pmmh_gamma_5_1, ax=axes[4][0], label = 'ABC-SMC Chain 1').set_title(rf'$\gamma$ mean = {gamma_mean_5}')
# ...

# %% [markdown]
# # ESS for PMCMC

# %%
pmmh_20_list = pmmh_20['arr0']

# %%
print(pmmh_20_list['beta'][19])
# Out:
# [0.41088818 0.41806377 0.46626753 ... 0.47145058 0.47145058 0.47145058]

# %%
ess_beta = (az.ess(pmmh_20_list['beta']))
ess_gamma = (az.ess(pmmh_20_list['gamma']))

print(ess_beta)
print(ess_gamma)
# Out:
# 10135.365495418644
# 10128.687544612561

# %%
print(10128.687544612561/20)
# Out:
# 506.43437723062806

# %%
print(ess_gamma/93.61831870405585/20)
# Out:
# 5.409564968065248

# %%
j = 0 
ess_list = []
for i in range(1, 21):
    print(az.ess(pmmh_20_list['gamma'][j:i]))
    ess_list.append(az.ess(pmmh_20_list['gamma'][j:i]))
    j += 1
# Out:
# 465.807568502647
# 622.0903388287379
# 610.9762205053544
# 492.8054067215137
# 596.4758456281913
# 452.69790083507434
# 502.7368901903473
# 421.36317757664693
# 551.106813158528
# 438.5088771806648
# 512.2087256436505
# 458.8497819591697
# 499.30482007533845
# 453.92428735369316
# 513.0037529883597
# 520.2451515475676
# 544.3620424211903
# 554.5075225184476
# 480.6484109416272
# 538.6861151440042

# %%
print(np.average(ess_list))
print(np.average(ess_list)/93.61831870405585)
# Out:
# 511.51548248603774
# 5.463839658379564

# %%
print(az.mean(pmmh_20_list['beta']))
print(az.mean(pmmh_20_list['gamma']))
# Out:
# 0.45
# 0.09

# %%
print(len(pmmh_20_list['beta'][0]))
# Out:
# 4000

# %%
print(np.mean(pmmh_20_list['beta']))
print(np.mean(pmmh_20_list['gamma']))
# Out:
# 0.4537487582050524
# 0.09042020803121914

# %%
summary('beta', 'gamma', pmmh_20_list['beta'], pmmh_20_list['gamma'], 4)
# Out:
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      beta  0.4537    0.0009  0.0297    0.4077    0.5028    0.4047    0.4992
# 1     gamma  0.0904    0.0005  0.0224    0.0593    0.1298    0.0565    0.1252
#
#      ess_bulk    ess_tail    rhat  mcse_mean  mcse_std
# 0  10135.3655  13519.4847  1.0014     0.0003    0.0002
# 1  10128.6875  12416.0761  1.0013     0.0002    0.0002

# %%
abcsmc_20_beta = abcsmc_20['arr0']
abcsmc_20_gamma = abcsmc_20['arr1']

# %%
summary('beta', 'gamma', abcsmc_20_beta, abcsmc_20_gamma, 4)
# Out:
#   Parameter    Mean  Variance     Std  eti95_lb  eti95_ub  hdi95_lb  hdi95_ub  \
# 0      beta  0.4626    0.0023  0.0482    0.3908    0.5439    0.3848    0.5371
# 1     gamma  0.0878    0.0028  0.0526    0.0141    0.1808    0.0000    0.1562
#
#      ess_bulk    ess_tail    rhat  mcse_mean  mcse_std
# 0  20160.4071  19945.1418  1.0003     0.0003    0.0002
# 1  19941.3870  19579.4248  1.0004     0.0004    0.0003

# %%
fig, axes = plt.subplots(2,2)


# BETA
for p in pmmh_20_list:
    sb.kdeplot(p['beta'], ax=axes[0][0])
for p in abcsmc_20_beta:
    sb.kdeplot(p, ax=axes[0][1])

axes[0][0].axvspan(0.4047, 0.4992, alpha=0.1, color='red')
axes[0][0].axvline(0.4047, color='red', linestyle='--', label = f'95% HDI [{0.4047:.3f}, {0.4992:.3f}]')
axes[0][0].axvline(0.4992, color='red', linestyle='--')

axes[0][1].axvspan(0.3848, 0.5371, alpha=0.1, color='red')
axes[0][1].axvline(0.3848, color='red', linestyle='--', label = f'95% HDI [{0.3848:.3f}, {0.5371:.3f}]')
axes[0][1].axvline(0.5371, color='red', linestyle='--')

axes[0][0].axvline(x = 0.4537, color='black', label = rf'$\beta$ mean estimate = 0.4537')
axes[0][1].axvline(x = 0.4626, color='black', label = rf'$\beta$ mean estimate = 0.4626')

# GAMMA
for p in pmmh_20_list:
    sb.kdeplot(p['gamma'], ax=axes[1][0])
for p in abcsmc_20_gamma:
    sb.kdeplot(p, ax=axes[1][1])


axes[1][0].axvspan(0.0565, 0.1252, alpha=0.1, color='red')
axes[1][0].axvline(0.0565, color='red', linestyle='--', label = f'95% HDI [{0.0565:.3f}, {0.1252:.3f}]')
axes[1][0].axvline(0.1252, color='red', linestyle='--')

axes[1][1].axvspan(0.0000, 0.1562, alpha=0.1, color='red')
axes[1][1].axvline(0.0000, color='red', linestyle='--', label = f'95% HDI [{0.0000:.3f}, {0.1562:.3f}]')
axes[1][1].axvline(0.1562, color='red', linestyle='--')

axes[1][0].axvline(x = 0.0904, color='black', label = rf'$\gamma$ mean estimate = 0.0904')
axes[1][1].axvline(x = 0.0878, color='black', label = rf'$\gamma$ mean estimate = 0.0878')

fig.set_figheight(8)
fig.set_figwidth(15)

axes[0][0].legend()
axes[0][1].legend()
axes[1][0].legend()
axes[1][1].legend()

axes[0][0].set_title('PMMH')
axes[0][1].set_title('ABC-SMC')


axes[0][0].set_ylabel(rf'$\beta$ Posterior Density')
axes[1][0].set_ylabel(rf'$\gamma$ Posterior Density')
axes[0][1].set_ylabel(rf'$\beta$ Posterior Density')
axes[1][1].set_ylabel(rf'$\gamma$ Posterior Density')

axes[0][0].set_xlabel(rf'$\beta$ values')
axes[1][0].set_xlabel(rf'$\gamma$ values')
axes[0][1].set_xlabel(rf'$\beta$ values')
axes[1][1].set_xlabel(rf'$\gamma$ values')


plt.setp(axes[0], xlim=(0.25, 0.75), ylim=(0, 16))
plt.setp(axes[1], xlim=(-0.1, 0.5), ylim=(0, 26))
# Out:
# [-0.1, 0.5, 0.0, 26.0, -0.1, 0.5, 0.0, 26.0]
