# %%
import matplotlib

# %matplotlib inline 
import warnings; warnings.simplefilter('ignore')    # hide warnings

from matplotlib import pyplot as plt
import numpy as np
import seaborn as sb
from scipy import stats
from scipy.stats import binom

import particles
from particles import distributions as dists
from particles import state_space_models as ssm
from particles.collectors import Moments
from particles import mcmc
from collections import OrderedDict

from epydemix import EpiModel
from epydemix import load_predefined_model
from epydemix.visualization import plot_quantiles, plot_trajectories, plot_posterior_distribution_2d
from epydemix.population import load_epydemix_population, Population, get_available_locations
from epydemix.visualization import plot_contact_matrix, plot_population
from epydemix.utils import compute_simulation_dates
from epydemix import simulate
from epydemix.calibration import ABCSampler, rmse
import matplotlib.pyplot as plt
import pandas as pd
import time

# %% [markdown]
# # Particles SIR Model

# %%
# class DiscreteDist copied from Particles documentation, no changes made except dim is 2 for multivariate
class DiscreteDist:
    dim = 2     # multivariate distribution (default is 1 for univariate)
    dtype = np.int64

    def shape(self, size):
        if size is None:
            return None
        else:
            return (size,) if self.dim == 1 else (size, self.dim)
        
    def logpdf(self, x):
        raise NotImplementedError
    
    def pdf(self, x):
        return np.exp(self.logpdf(x))
    
    def rvs(self, size=None):
        raise NotImplementedError
    
    def ppf(self, u):
        raise NotImplementedError
    

# changed the order of n & p to align with scipy.stats documentation
class NegativeBinomial(DiscreteDist):
    def __init__(self, n=1, p=0.5):
        self.n = n
        self.p = p
    def rvs(self, size = None):
        return np.random.negative_binomial(self.n, self.p, size=size)
    def logpdf(self,x):
        return stats.nbinom.logpmf(x, self.n, self.p) # changed the order of n & p
    def ppf(self, u):
        return stats.nbinom.ppf(u, self.n, self.p) # changed the order of n & p

# %%
def Initial(N):  # where xp = X_{t-1}
    
    chainrule = OrderedDict()
    chainrule['new_inf'] = dists.Dirac(0)
    chainrule['new_rec'] = dists.Dirac(0)
    chainrule['S'] = dists.Dirac(N-1)
    chainrule['I'] = dists.Dirac(1)
    chainrule['R'] = dists.Dirac(0)
    return dists.StructDist(chainrule)

# Chain binomial process
def Binomial(xp, beta, gamma, N):  # where xp = X_{t-1}
    # probabilites for new infetions and recoveries
    infection_prob = 1 - np.exp(-beta * xp['I'] / N)
    recovery_prob = 1 - np.exp(-gamma)
    # probability = np.clip(probability, 0, 1)
    
    # Update compartments
    chainrule = OrderedDict()
    chainrule['new_inf'] = dists.Binomial(n = xp['S'].astype(int), p = infection_prob)
    chainrule['new_rec'] = dists.Binomial(n = xp['I'].astype(int), p = recovery_prob)
    chainrule['S'] = dists.Cond(lambda x: dists.Dirac(xp['S'].astype(int) - x['new_inf']))
    chainrule['I'] = dists.Cond(lambda x: dists.Dirac(xp['I'].astype(int) + x['new_inf'] - x['new_rec']))
    chainrule['R'] = dists.Cond(lambda x: dists.Dirac(xp['R'].astype(int) + x['new_rec']))
    return dists.StructDist(chainrule)

# %%
# State Space Model

class ChainBinomialModel(ssm.StateSpaceModel):
    default_params = {'N': 10000}
    def PX0(self):                                                      # Initial state of SIR
        return Initial(10000)
    def PX(self, t, xp):                                                # Hidden Markov process
        return Binomial(xp, self.beta, self.gamma, self.N)
    def PY(self, t, xp, x):                                             # Observation model 
        mu = 0.05 * x['I']
        size = 2
        mu2 = np.maximum(mu, 1e-6)
        p = size/(size + mu2)
        return NegativeBinomial(n = size, p = p)

# %%
ChainBin = ChainBinomialModel(beta = 0.3, gamma = 0.1)
x, y = ChainBin.simulate(100)

# %%
plt.style.use('ggplot')
plt.plot([xt['S'] for xt in x], label=r'$S_t$')
plt.plot([xt['I'] for xt in x], label=r'$I_t$')
plt.plot([xt['R'] for xt in x], label=r'$R_t$')
plt.plot([xt['new_inf'] for xt in x], label='new_inf')
plt.plot([xt['new_rec'] for xt in x], label='new_rec')
plt.legend()

# %%
plt.style.use('ggplot')
plt.plot(y, label=r'$Y_t$', linestyle='', marker='o')

plt.legend()

# %%
fk = ssm.Bootstrap(ssm=ChainBin, data=y)
alg = particles.SMC(fk=fk, 
                    N=100,
                    resampling = 'systematic', 
                    verbose=True)
alg.run()
# Out:
# t=0: resample:False, ESS (end of iter)=100.00
# t=1: resample:False, ESS (end of iter)=81.59
# t=2: resample:False, ESS (end of iter)=84.15
# t=3: resample:False, ESS (end of iter)=47.86
# t=4: resample:True, ESS (end of iter)=80.69
# t=5: resample:False, ESS (end of iter)=59.33
# t=6: resample:False, ESS (end of iter)=47.12
# t=7: resample:True, ESS (end of iter)=95.58
# t=8: resample:False, ESS (end of iter)=82.27
# t=9: resample:False, ESS (end of iter)=63.84
# t=10: resample:False, ESS (end of iter)=85.05
# t=11: resample:False, ESS (end of iter)=72.10
# t=12: resample:False, ESS (end of iter)=68.65
# t=13: resample:False, ESS (end of iter)=51.35
# t=14: resample:False, ESS (end of iter)=47.08
# t=15: resample:True, ESS (end of iter)=83.81
# t=16: resample:False, ESS (end of iter)=54.23
# t=17: resample:False, ESS (end of iter)=80.54
# t=18: resample:False, ESS (end of iter)=78.94
# t=19: resample:False, ESS (end of iter)=65.76
# t=20: resample:False, ESS (end of iter)=48.28
# t=21: resample:True, ESS (end of iter)=77.95
# t=22: resample:False, ESS (end of iter)=92.62
# t=23: resample:False, ESS (end of iter)=85.70
# t=24: resample:False, ESS (end of iter)=82.13
# t=25: resample:False, ESS (end of iter)=67.92
# t=26: resample:False, ESS (end of iter)=68.28
# t=27: resample:False, ESS (end of iter)=67.41
# t=28: resample:False, ESS (end of iter)=64.35
# t=29: resample:False, ESS (end of iter)=59.95
# t=30: resample:False, ESS (end of iter)=55.66
# t=31: resample:False, ESS (end of iter)=51.29
# t=32: resample:False, ESS (end of iter)=46.72
# t=33: resample:True, ESS (end of iter)=91.59
# t=34: resample:False, ESS (end of iter)=98.71
# t=35: resample:False, ESS (end of iter)=95.71
# t=36: resample:False, ESS (end of iter)=80.77
# t=37: resample:False, ESS (end of iter)=86.15
# t=38: resample:False, ESS (end of iter)=72.14
# t=39: resample:False, ESS (end of iter)=50.03
# t=40: resample:False, ESS (end of iter)=41.70
# t=41: resample:True, ESS (end of iter)=99.87
# t=42: resample:False, ESS (end of iter)=98.94
# t=43: resample:False, ESS (end of iter)=94.73
# t=44: resample:False, ESS (end of iter)=88.10
# t=45: resample:False, ESS (end of iter)=82.41
# t=46: resample:False, ESS (end of iter)=90.17
# t=47: resample:False, ESS (end of iter)=92.07
# t=48: resample:False, ESS (end of iter)=93.26
# t=49: resample:False, ESS (end of iter)=92.67
# t=50: resample:False, ESS (end of iter)=93.37
# t=51: resample:False, ESS (end of iter)=93.66
# t=52: resample:False, ESS (end of iter)=92.86
# t=53: resample:False, ESS (end of iter)=93.29
# t=54: resample:False, ESS (end of iter)=92.39
# t=55: resample:False, ESS (end of iter)=92.57
# t=56: resample:False, ESS (end of iter)=91.97
# t=57: resample:False, ESS (end of iter)=93.72
# t=58: resample:False, ESS (end of iter)=92.04
# t=59: resample:False, ESS (end of iter)=95.20
# t=60: resample:False, ESS (end of iter)=95.74
# t=61: resample:False, ESS (end of iter)=92.01
# t=62: resample:False, ESS (end of iter)=94.98
# t=63: resample:False, ESS (end of iter)=97.18
# t=64: resample:False, ESS (end of iter)=92.49
# t=65: resample:False, ESS (end of iter)=94.54
# t=66: resample:False, ESS (end of iter)=91.65
# t=67: resample:False, ESS (end of iter)=94.45
# t=68: resample:False, ESS (end of iter)=96.39
# t=69: resample:False, ESS (end of iter)=97.12
# t=70: resample:False, ESS (end of iter)=96.74
# t=71: resample:False, ESS (end of iter)=97.02
# t=72: resample:False, ESS (end of iter)=95.80
# t=73: resample:False, ESS (end of iter)=96.57
# t=74: resample:False, ESS (end of iter)=96.42
# t=75: resample:False, ESS (end of iter)=95.57
# t=76: resample:False, ESS (end of iter)=95.03
# t=77: resample:False, ESS (end of iter)=95.76
# t=78: resample:False, ESS (end of iter)=94.11
# t=79: resample:False, ESS (end of iter)=94.42
# t=80: resample:False, ESS (end of iter)=91.88
# t=81: resample:False, ESS (end of iter)=90.17
# t=82: resample:False, ESS (end of iter)=64.51
# t=83: resample:False, ESS (end of iter)=55.16
# t=84: resample:False, ESS (end of iter)=59.92
# t=85: resample:False, ESS (end of iter)=65.08
# t=86: resample:False, ESS (end of iter)=71.57
# t=87: resample:False, ESS (end of iter)=74.62
# t=88: resample:False, ESS (end of iter)=77.92
# t=89: resample:False, ESS (end of iter)=72.65
# t=90: resample:False, ESS (end of iter)=66.11
# t=91: resample:False, ESS (end of iter)=71.31
# t=92: resample:False, ESS (end of iter)=76.73
# t=93: resample:False, ESS (end of iter)=79.09
# t=94: resample:False, ESS (end of iter)=63.58
# t=95: resample:False, ESS (end of iter)=56.90
# t=96: resample:False, ESS (end of iter)=62.97
# t=97: resample:False, ESS (end of iter)=64.81
# t=98: resample:False, ESS (end of iter)=63.77
# t=99: resample:False, ESS (end of iter)=57.23

# %%
print(alg.cpu_time)
# Out:
# 0.02006458304822445

# %%
outf = lambda pf: pf.logLt
alg_parallel = particles.multiSMC(fk=fk,
                                  N=[100, 500, 1000],
                                  resampling='systematic',
                                  verbose=True,
                                  )
# Out:
# t=0: resample:False, ESS (end of iter)=1000.00
# t=1: resample:False, ESS (end of iter)=812.85
# t=2: resample:False, ESS (end of iter)=835.39
# t=3: resample:False, ESS (end of iter)=498.46
# t=0: resample:False, ESS (end of iter)=500.00
# t=1: resample:False, ESS (end of iter)=412.47
# t=2: resample:False, ESS (end of iter)=422.30
# t=3: resample:False, ESS (end of iter)=267.91
# t=0: resample:False, ESS (end of iter)=100.00
# t=4: resample:False, ESS (end of iter)=161.73
# t=1: resample:False, ESS (end of iter)=82.92
# t=2: resample:False, ESS (end of iter)=85.00
# t=3: resample:False, ESS (end of iter)=57.48
# t=4: resample:False, ESS (end of iter)=37.36
# t=0: resample:False, ESS (end of iter)=100.00
# t=1: resample:False, ESS (end of iter)=82.27
# t=2: resample:False, ESS (end of iter)=84.58
# t=3: resample:False, ESS (end of iter)=52.55
# t=4: resample:False, ESS (end of iter)=33.67
# t=0: resample:False, ESS (end of iter)=500.00
# t=1: resample:False, ESS (end of iter)=407.96
# t=2: resample:False, ESS (end of iter)=419.38
# t=3: resample:False, ESS (end of iter)=256.33
# t=4: resample:False, ESS (end of iter)=148.60
# t=0: resample:False, ESS (end of iter)=500.00
# t=1: resample:False, ESS (end of iter)=419.74
# t=2: resample:False, ESS (end of iter)=427.93
# t=3: resample:False, ESS (end of iter)=271.59
# t=4: resample:False, ESS (end of iter)=159.61
# t=0: resample:False, ESS (end of iter)=100.00
# t=1: resample:False, ESS (end of iter)=79.78
# t=2: resample:False, ESS (end of iter)=80.77
# t=3: resample:False, ESS (end of iter)=54.88
# t=4: resample:False, ESS (end of iter)=37.18
# t=0: resample:False, ESS (end of iter)=100.00
# t=1: resample:False, ESS (end of iter)=80.51
# t=2: resample:False, ESS (end of iter)=82.96
# t=3: resample:False, ESS (end of iter)=46.97
# t=0: resample:False, ESS (end of iter)=1000.00
# t=1: resample:False, ESS (end of iter)=822.49
# t=2: resample:False, ESS (end of iter)=843.68
# t=3: resample:False, ESS (end of iter)=515.88
# t=4: resample:False, ESS (end of iter)=294.11
# t=0: resample:False, ESS (end of iter)=1000.00
# t=1: resample:False, ESS (end of iter)=817.02
# t=2: resample:False, ESS (end of iter)=837.40
# t=3: resample:False, ESS (end of iter)=529.50
# t=4: resample:False, ESS (end of iter)=315.42
# t=4: resample:True, ESS (end of iter)=807.59
# t=5: resample:False, ESS (end of iter)=588.73
# t=6: resample:False, ESS (end of iter)=455.87
# t=7: resample:True, ESS (end of iter)=961.50
# t=8: resample:False, ESS (end of iter)=842.98
# t=9: resample:False, ESS (end of iter)=662.72
# t=10: resample:False, ESS (end of iter)=875.15
# t=11: resample:False, ESS (end of iter)=777.10
# t=12: resample:False, ESS (end of iter)=742.21
# t=13: resample:False, ESS (end of iter)=607.22
# t=14: resample:False, ESS (end of iter)=561.12
# t=15: resample:False, ESS (end of iter)=425.28
# t=16: resample:True, ESS (end of iter)=853.13
# t=17: resample:False, ESS (end of iter)=939.27
# t=18: resample:False, ESS (end of iter)=877.31
# t=19: resample:False, ESS (end of iter)=830.02
# t=20: resample:False, ESS (end of iter)=667.17
# t=21: resample:False, ESS (end of iter)=461.20
# t=22: resample:True, ESS (end of iter)=787.85
# t=23: resample:False, ESS (end of iter)=895.45
# t=24: resample:False, ESS (end of iter)=736.30
# t=25: resample:False, ESS (end of iter)=545.01
# t=26: resample:False, ESS (end of iter)=595.60
# t=27: resample:False, ESS (end of iter)=630.76
# t=28: resample:False, ESS (end of iter)=626.70
# t=29: resample:False, ESS (end of iter)=640.59
# t=30: resample:False, ESS (end of iter)=614.50
# t=31: resample:False, ESS (end of iter)=490.65
# t=32: resample:True, ESS (end of iter)=970.33
# t=33: resample:False, ESS (end of iter)=832.94
# t=34: resample:False, ESS (end of iter)=948.12
# t=35: resample:False, ESS (end of iter)=888.92
# t=36: resample:False, ESS (end of iter)=708.06
# t=37: resample:False, ESS (end of iter)=769.01
# t=38: resample:False, ESS (end of iter)=618.76
# t=39: resample:False, ESS (end of iter)=402.57
# t=40: resample:True, ESS (end of iter)=967.83
# t=41: resample:False, ESS (end of iter)=953.27
# t=42: resample:False, ESS (end of iter)=988.27
# t=43: resample:False, ESS (end of iter)=993.84
# t=44: resample:False, ESS (end of iter)=967.23
# t=45: resample:False, ESS (end of iter)=930.86
# t=46: resample:False, ESS (end of iter)=978.08
# t=47: resample:False, ESS (end of iter)=984.95
# t=48: resample:False, ESS (end of iter)=987.45
# t=49: resample:False, ESS (end of iter)=986.45
# t=50: resample:False, ESS (end of iter)=982.57
# t=51: resample:False, ESS (end of iter)=986.30
# t=52: resample:False, ESS (end of iter)=981.49
# t=53: resample:False, ESS (end of iter)=983.82
# t=54: resample:False, ESS (end of iter)=979.58
# t=55: resample:False, ESS (end of iter)=980.41
# t=56: resample:False, ESS (end of iter)=977.82
# t=57: resample:False, ESS (end of iter)=983.70
# t=58: resample:False, ESS (end of iter)=978.05
# t=59: resample:False, ESS (end of iter)=985.24
# t=60: resample:False, ESS (end of iter)=984.78
# t=61: resample:False, ESS (end of iter)=977.51
# t=62: resample:False, ESS (end of iter)=982.99
# t=63: resample:False, ESS (end of iter)=977.21
# t=64: resample:False, ESS (end of iter)=977.84
# t=65: resample:False, ESS (end of iter)=980.12
# t=66: resample:False, ESS (end of iter)=974.04
# t=67: resample:False, ESS (end of iter)=977.69
# t=68: resample:False, ESS (end of iter)=971.69
# t=69: resample:False, ESS (end of iter)=959.91
# t=70: resample:False, ESS (end of iter)=962.60
# t=71: resample:False, ESS (end of iter)=947.38
# t=72: resample:False, ESS (end of iter)=903.18
# t=73: resample:False, ESS (end of iter)=934.78
# t=74: resample:False, ESS (end of iter)=940.93
# t=75: resample:False, ESS (end of iter)=954.25
# t=76: resample:False, ESS (end of iter)=954.43
# t=77: resample:False, ESS (end of iter)=930.00
# t=78: resample:False, ESS (end of iter)=893.41
# t=79: resample:False, ESS (end of iter)=901.66
# t=80: resample:False, ESS (end of iter)=941.33
# t=81: resample:False, ESS (end of iter)=935.64
# t=82: resample:False, ESS (end of iter)=780.08
# t=83: resample:False, ESS (end of iter)=702.26
# t=84: resample:False, ESS (end of iter)=744.89
# t=85: resample:False, ESS (end of iter)=783.62
# t=86: resample:False, ESS (end of iter)=824.39
# t=5: resample:True, ESS (end of iter)=443.56
# t=6: resample:False, ESS (end of iter)=372.65
# t=87: resample:False, ESS (end of iter)=838.91
# t=7: resample:False, ESS (end of iter)=404.16
# t=8: resample:False, ESS (end of iter)=423.59
# t=88: resample:False, ESS (end of iter)=851.94
# t=9: resample:False, ESS (end of iter)=420.44
# t=10: resample:False, ESS (end of iter)=359.40
# t=89: resample:False, ESS (end of iter)=825.83
# t=11: resample:False, ESS (end of iter)=375.60
# t=12: resample:False, ESS (end of iter)=357.83
# t=90: resample:False, ESS (end of iter)=787.67
# t=13: resample:False, ESS (end of iter)=343.43
# t=14: resample:False, ESS (end of iter)=322.88t=91: resample:False, ESS (end of iter)=816.85
#
# t=15: resample:False, ESS (end of iter)=272.70
# t=16: resample:False, ESS (end of iter)=204.37
# t=17: resample:True, ESS (end of iter)=420.35
# t=92: resample:False, ESS (end of iter)=837.83
# t=18: resample:False, ESS (end of iter)=363.66
# t=19: resample:False, ESS (end of iter)=420.89
# t=93: resample:False, ESS (end of iter)=839.84
# t=20: resample:False, ESS (end of iter)=397.78
# t=21: resample:False, ESS (end of iter)=309.29
# t=22: resample:False, ESS (end of iter)=351.16
# t=23: resample:False, ESS (end of iter)=309.39
# t=94: resample:False, ESS (end of iter)=758.29
# t=24: resample:False, ESS (end of iter)=309.70
# t=25: resample:False, ESS (end of iter)=284.82
# t=95: resample:False, ESS (end of iter)=695.20
# t=26: resample:False, ESS (end of iter)=275.35
# t=96: resample:False, ESS (end of iter)=750.24
# t=27: resample:False, ESS (end of iter)=262.35
# t=97: resample:False, ESS (end of iter)=764.50
# t=28: resample:False, ESS (end of iter)=248.02
# t=5: resample:True, ESS (end of iter)=89.49
# t=98: resample:False, ESS (end of iter)=753.69
# t=6: resample:False, ESS (end of iter)=73.88
# t=7: resample:False, ESS (end of iter)=81.90
# t=29: resample:True, ESS (end of iter)=425.30
# t=8: resample:False, ESS (end of iter)=86.46
# t=99: resample:False, ESS (end of iter)=679.56
# t=9: resample:False, ESS (end of iter)=85.25
# t=30: resample:False, ESS (end of iter)=363.81
# t=10: resample:False, ESS (end of iter)=70.97
# t=11: resample:False, ESS (end of iter)=75.48
# t=31: resample:False, ESS (end of iter)=428.37
# t=12: resample:False, ESS (end of iter)=71.04
# t=13: resample:False, ESS (end of iter)=68.69
# t=32: resample:False, ESS (end of iter)=388.11
# t=14: resample:False, ESS (end of iter)=64.22
# t=33: resample:False, ESS (end of iter)=315.90
# t=15: resample:False, ESS (end of iter)=55.22
# t=16: resample:False, ESS (end of iter)=44.50
# t=34: resample:False, ESS (end of iter)=374.37
# t=17: resample:True, ESS (end of iter)=82.19
# t=18: resample:False, ESS (end of iter)=70.03
# t=35: resample:False, ESS (end of iter)=341.45
# t=19: resample:False, ESS (end of iter)=81.06
# t=36: resample:False, ESS (end of iter)=263.61
# t=20: resample:False, ESS (end of iter)=81.91
# t=21: resample:False, ESS (end of iter)=71.86
# t=37: resample:False, ESS (end of iter)=288.04
# t=22: resample:False, ESS (end of iter)=72.24
# t=38: resample:False, ESS (end of iter)=228.83
# t=23: resample:False, ESS (end of iter)=66.72
# t=24: resample:False, ESS (end of iter)=64.62
# t=39: resample:True, ESS (end of iter)=417.46
# t=25: resample:False, ESS (end of iter)=61.02
# t=40: resample:False, ESS (end of iter)=358.51
# t=26: resample:False, ESS (end of iter)=59.54
# t=41: resample:False, ESS (end of iter)=346.16
# t=27: resample:False, ESS (end of iter)=57.18
# t=42: resample:False, ESS (end of iter)=390.35
# t=28: resample:False, ESS (end of iter)=54.82
# t=29: resample:False, ESS (end of iter)=51.52
# t=43: resample:False, ESS (end of iter)=429.25
# t=30: resample:False, ESS (end of iter)=48.52
# t=31: resample:True, ESS (end of iter)=60.34
# t=32: resample:False, ESS (end of iter)=52.06
# t=33: resample:False, ESS (end of iter)=39.55
# t=34: resample:True, ESS (end of iter)=96.89
# t=35: resample:False, ESS (end of iter)=99.53
# t=44: resample:False, ESS (end of iter)=458.33
# t=36: resample:False, ESS (end of iter)=95.76
# t=45: resample:False, ESS (end of iter)=471.41
# t=37: resample:False, ESS (end of iter)=97.82
# t=46: resample:False, ESS (end of iter)=449.99
# t=38: resample:False, ESS (end of iter)=88.75
# t=39: resample:False, ESS (end of iter)=71.05
# t=47: resample:False, ESS (end of iter)=441.19
# t=40: resample:False, ESS (end of iter)=63.68
# t=41: resample:False, ESS (end of iter)=61.50
# t=48: resample:False, ESS (end of iter)=433.88
# t=42: resample:False, ESS (end of iter)=65.52
# t=49: resample:False, ESS (end of iter)=437.58
# t=43: resample:False, ESS (end of iter)=69.94
# t=5: resample:True, ESS (end of iter)=90.93
# t=44: resample:False, ESS (end of iter)=74.31
# t=6: resample:False, ESS (end of iter)=77.25
# t=7: resample:False, ESS (end of iter)=83.67
# t=8: resample:False, ESS (end of iter)=87.71
# t=45: resample:False, ESS (end of iter)=77.13
# t=9: resample:False, ESS (end of iter)=87.62
# t=10: resample:False, ESS (end of iter)=73.13
# t=11: resample:False, ESS (end of iter)=77.12
# t=46: resample:False, ESS (end of iter)=71.93
# t=12: resample:False, ESS (end of iter)=73.78
# t=50: resample:False, ESS (end of iter)=428.33
# t=13: resample:False, ESS (end of iter)=71.95
# t=14: resample:False, ESS (end of iter)=68.57
# t=47: resample:False, ESS (end of iter)=70.10
# t=5: resample:True, ESS (end of iter)=436.25
# t=15: resample:False, ESS (end of iter)=57.33
# t=16: resample:False, ESS (end of iter)=39.07
# t=48: resample:False, ESS (end of iter)=68.60
# t=6: resample:False, ESS (end of iter)=358.17
# t=17: resample:True, ESS (end of iter)=81.08
# t=18: resample:False, ESS (end of iter)=68.04
# t=51: resample:False, ESS (end of iter)=429.89
# t=7: resample:False, ESS (end of iter)=394.62
# t=19: resample:False, ESS (end of iter)=82.24
# t=49: resample:False, ESS (end of iter)=69.45
# t=20: resample:False, ESS (end of iter)=80.52
# t=8: resample:False, ESS (end of iter)=415.47
# t=50: resample:False, ESS (end of iter)=66.44
# t=21: resample:False, ESS (end of iter)=65.39
# t=9: resample:False, ESS (end of iter)=407.30
# t=22: resample:False, ESS (end of iter)=71.55
# t=51: resample:False, ESS (end of iter)=67.23
# t=52: resample:False, ESS (end of iter)=431.05
# t=52: resample:False, ESS (end of iter)=66.78
# t=10: resample:False, ESS (end of iter)=348.92t=23: resample:False, ESS (end of iter)=62.06
#
# t=53: resample:False, ESS (end of iter)=66.86
# t=54: resample:False, ESS (end of iter)=66.84
# t=55: resample:False, ESS (end of iter)=66.81
# t=56: resample:False, ESS (end of iter)=66.92
# t=24: resample:False, ESS (end of iter)=62.69
# t=57: resample:False, ESS (end of iter)=66.30
# t=58: resample:False, ESS (end of iter)=66.79
# t=11: resample:False, ESS (end of iter)=366.38
# t=53: resample:False, ESS (end of iter)=429.76
# t=59: resample:False, ESS (end of iter)=65.50
# t=25: resample:False, ESS (end of iter)=57.88
# t=60: resample:False, ESS (end of iter)=65.06
# t=61: resample:False, ESS (end of iter)=66.72
# t=62: resample:False, ESS (end of iter)=65.05
# t=63: resample:False, ESS (end of iter)=63.01
# t=54: resample:False, ESS (end of iter)=433.11
# t=12: resample:False, ESS (end of iter)=346.98
# t=26: resample:False, ESS (end of iter)=54.68
# t=64: resample:False, ESS (end of iter)=65.81
# t=65: resample:False, ESS (end of iter)=64.33
# t=66: resample:False, ESS (end of iter)=65.78
# t=67: resample:False, ESS (end of iter)=63.79
# t=27: resample:False, ESS (end of iter)=51.02
# t=68: resample:False, ESS (end of iter)=61.52
# t=55: resample:False, ESS (end of iter)=432.23
# t=69: resample:False, ESS (end of iter)=59.58
# t=70: resample:False, ESS (end of iter)=59.81
# t=13: resample:False, ESS (end of iter)=329.70
# t=71: resample:False, ESS (end of iter)=57.73
# t=28: resample:False, ESS (end of iter)=47.91
# t=72: resample:False, ESS (end of iter)=53.91
# t=56: resample:False, ESS (end of iter)=434.46
# t=73: resample:False, ESS (end of iter)=56.23
# t=74: resample:False, ESS (end of iter)=56.70
# t=29: resample:True, ESS (end of iter)=84.66
# t=14: resample:False, ESS (end of iter)=306.46
# t=75: resample:False, ESS (end of iter)=58.62
# t=57: resample:False, ESS (end of iter)=426.16
# t=76: resample:False, ESS (end of iter)=58.90
# t=77: resample:False, ESS (end of iter)=54.82
# t=30: resample:False, ESS (end of iter)=72.96
# t=78: resample:False, ESS (end of iter)=50.91
# t=15: resample:False, ESS (end of iter)=262.24
# t=79: resample:False, ESS (end of iter)=51.37
# t=58: resample:False, ESS (end of iter)=433.83
# t=31: resample:False, ESS (end of iter)=86.02
# t=32: resample:False, ESS (end of iter)=77.37
# t=80: resample:False, ESS (end of iter)=58.96
# t=16: resample:False, ESS (end of iter)=207.81
# t=59: resample:False, ESS (end of iter)=416.00
# t=81: resample:False, ESS (end of iter)=59.73
# t=33: resample:False, ESS (end of iter)=61.32
# t=82: resample:False, ESS (end of iter)=65.65
# t=83: resample:False, ESS (end of iter)=65.50
# t=34: resample:False, ESS (end of iter)=74.03
# t=60: resample:False, ESS (end of iter)=411.19
# t=17: resample:True, ESS (end of iter)=410.41
# t=84: resample:False, ESS (end of iter)=65.37
# t=35: resample:False, ESS (end of iter)=66.98
# t=85: resample:False, ESS (end of iter)=64.80
# t=86: resample:False, ESS (end of iter)=63.44
# t=18: resample:False, ESS (end of iter)=349.95
# t=36: resample:False, ESS (end of iter)=51.08
# t=61: resample:False, ESS (end of iter)=432.81
# t=87: resample:False, ESS (end of iter)=62.50
# t=37: resample:False, ESS (end of iter)=55.91
# t=88: resample:False, ESS (end of iter)=61.28
# t=89: resample:False, ESS (end of iter)=62.51
# t=38: resample:False, ESS (end of iter)=43.97
# t=62: resample:False, ESS (end of iter)=415.08
# t=90: resample:False, ESS (end of iter)=62.79
# t=91: resample:False, ESS (end of iter)=62.41
# t=92: resample:False, ESS (end of iter)=61.23
# t=93: resample:False, ESS (end of iter)=59.98
# t=19: resample:False, ESS (end of iter)=403.63
# t=94: resample:False, ESS (end of iter)=60.23
# t=39: resample:True, ESS (end of iter)=78.86
# t=95: resample:False, ESS (end of iter)=58.09
# t=63: resample:False, ESS (end of iter)=392.41
# t=96: resample:False, ESS (end of iter)=59.84
# t=97: resample:False, ESS (end of iter)=60.20
# t=98: resample:False, ESS (end of iter)=59.97
# t=40: resample:False, ESS (end of iter)=66.17
# t=99: resample:False, ESS (end of iter)=56.43
# t=64: resample:False, ESS (end of iter)=428.01
# t=41: resample:False, ESS (end of iter)=63.86t=20: resample:False, ESS (end of iter)=393.71
#
# t=42: resample:False, ESS (end of iter)=73.36t=5: resample:True, ESS (end of iter)=881.46
#
# t=65: resample:False, ESS (end of iter)=414.97
# t=21: resample:False, ESS (end of iter)=331.70
# t=43: resample:False, ESS (end of iter)=82.65
# t=6: resample:False, ESS (end of iter)=732.29
# t=66: resample:False, ESS (end of iter)=430.23
# t=44: resample:False, ESS (end of iter)=90.01
# t=22: resample:False, ESS (end of iter)=340.31
# t=7: resample:False, ESS (end of iter)=811.80
# t=45: resample:False, ESS (end of iter)=93.21
# t=8: resample:False, ESS (end of iter)=853.77
# t=67: resample:False, ESS (end of iter)=412.94
# t=46: resample:False, ESS (end of iter)=88.24
# t=23: resample:False, ESS (end of iter)=306.19
# t=9: resample:False, ESS (end of iter)=832.64
# t=47: resample:False, ESS (end of iter)=86.19
# t=68: resample:False, ESS (end of iter)=392.83
# t=48: resample:False, ESS (end of iter)=84.47
# t=10: resample:False, ESS (end of iter)=724.59
# t=24: resample:False, ESS (end of iter)=304.07
# t=49: resample:False, ESS (end of iter)=85.32
# t=11: resample:False, ESS (end of iter)=744.73
# t=69: resample:False, ESS (end of iter)=375.65
# t=50: resample:False, ESS (end of iter)=83.18
# t=25: resample:False, ESS (end of iter)=284.06
# t=12: resample:False, ESS (end of iter)=703.56
# t=51: resample:False, ESS (end of iter)=83.37
# t=70: resample:False, ESS (end of iter)=380.86
# t=13: resample:False, ESS (end of iter)=651.51
# t=52: resample:False, ESS (end of iter)=83.87
# t=53: resample:False, ESS (end of iter)=83.50
# t=14: resample:False, ESS (end of iter)=605.06
# t=71: resample:False, ESS (end of iter)=363.60
# t=54: resample:False, ESS (end of iter)=84.38
# t=72: resample:False, ESS (end of iter)=328.42
# t=55: resample:False, ESS (end of iter)=84.17
# t=15: resample:False, ESS (end of iter)=515.28
# t=26: resample:False, ESS (end of iter)=275.48
# t=56: resample:False, ESS (end of iter)=84.77
# t=73: resample:False, ESS (end of iter)=354.29
# t=57: resample:False, ESS (end of iter)=82.68
# t=58: resample:False, ESS (end of iter)=84.65
# t=27: resample:False, ESS (end of iter)=262.09t=16: resample:False, ESS (end of iter)=415.52
#
# t=59: resample:False, ESS (end of iter)=80.21
# t=60: resample:False, ESS (end of iter)=79.08
# t=74: resample:False, ESS (end of iter)=361.92
# t=61: resample:False, ESS (end of iter)=84.50
# t=62: resample:False, ESS (end of iter)=80.02
# t=63: resample:False, ESS (end of iter)=74.51
# t=64: resample:False, ESS (end of iter)=83.44
# t=28: resample:False, ESS (end of iter)=248.18
# t=65: resample:False, ESS (end of iter)=80.20
# t=75: resample:False, ESS (end of iter)=382.45
# t=66: resample:False, ESS (end of iter)=84.16
# t=17: resample:True, ESS (end of iter)=843.89
# t=67: resample:False, ESS (end of iter)=79.96
# t=68: resample:False, ESS (end of iter)=75.01
# t=69: resample:False, ESS (end of iter)=70.86
# t=29: resample:True, ESS (end of iter)=434.35
# t=70: resample:False, ESS (end of iter)=72.39
# t=71: resample:False, ESS (end of iter)=68.30
# t=76: resample:False, ESS (end of iter)=386.88
# t=72: resample:False, ESS (end of iter)=59.97
# t=18: resample:False, ESS (end of iter)=734.06
# t=73: resample:False, ESS (end of iter)=66.35
# t=74: resample:False, ESS (end of iter)=68.28
# t=30: resample:False, ESS (end of iter)=378.20
# t=75: resample:False, ESS (end of iter)=73.41
# t=77: resample:False, ESS (end of iter)=355.35
# t=76: resample:False, ESS (end of iter)=74.59
# t=77: resample:False, ESS (end of iter)=67.29
# t=19: resample:False, ESS (end of iter)=838.71
# t=78: resample:False, ESS (end of iter)=60.88
# t=31: resample:False, ESS (end of iter)=425.18
# t=79: resample:False, ESS (end of iter)=62.56
# t=78: resample:False, ESS (end of iter)=325.10t=80: resample:False, ESS (end of iter)=76.92
#
# t=81: resample:False, ESS (end of iter)=78.18
# t=32: resample:False, ESS (end of iter)=381.43
# t=82: resample:False, ESS (end of iter)=73.72
# t=83: resample:False, ESS (end of iter)=67.54
# t=33: resample:False, ESS (end of iter)=305.25
# t=84: resample:False, ESS (end of iter)=70.72
# t=79: resample:False, ESS (end of iter)=333.10
# t=85: resample:False, ESS (end of iter)=73.05
# t=34: resample:False, ESS (end of iter)=365.25
# t=86: resample:False, ESS (end of iter)=74.70
# t=87: resample:False, ESS (end of iter)=74.99
# t=35: resample:False, ESS (end of iter)=330.49
# t=88: resample:False, ESS (end of iter)=74.83
# t=20: resample:False, ESS (end of iter)=810.22
# t=36: resample:False, ESS (end of iter)=250.60
# t=89: resample:False, ESS (end of iter)=73.94
# t=80: resample:False, ESS (end of iter)=395.00
# t=90: resample:False, ESS (end of iter)=71.59
# t=37: resample:False, ESS (end of iter)=274.57
# t=91: resample:False, ESS (end of iter)=73.10
# t=92: resample:False, ESS (end of iter)=73.56
# t=38: resample:False, ESS (end of iter)=215.72
# t=93: resample:False, ESS (end of iter)=73.19
# t=94: resample:False, ESS (end of iter)=68.09
# t=39: resample:True, ESS (end of iter)=423.56
# t=81: resample:False, ESS (end of iter)=399.22
# t=95: resample:False, ESS (end of iter)=62.63
# t=21: resample:False, ESS (end of iter)=644.57
# t=40: resample:False, ESS (end of iter)=368.60
# t=96: resample:False, ESS (end of iter)=66.81
# t=97: resample:False, ESS (end of iter)=67.66
# t=41: resample:False, ESS (end of iter)=355.69
# t=98: resample:False, ESS (end of iter)=66.93
# t=99: resample:False, ESS (end of iter)=62.48
# t=42: resample:False, ESS (end of iter)=394.32
# t=43: resample:False, ESS (end of iter)=430.57
# t=44: resample:False, ESS (end of iter)=458.61
# t=82: resample:False, ESS (end of iter)=391.10
# t=45: resample:False, ESS (end of iter)=471.28
# t=46: resample:False, ESS (end of iter)=449.97
# t=47: resample:False, ESS (end of iter)=441.05
# t=83: resample:False, ESS (end of iter)=368.43
# t=48: resample:False, ESS (end of iter)=433.48
# t=49: resample:False, ESS (end of iter)=437.49
# t=50: resample:False, ESS (end of iter)=426.59
# t=84: resample:False, ESS (end of iter)=381.06
# t=51: resample:False, ESS (end of iter)=428.88
# t=52: resample:False, ESS (end of iter)=429.17
# t=85: resample:False, ESS (end of iter)=390.08t=53: resample:False, ESS (end of iter)=428.06
#
# t=54: resample:False, ESS (end of iter)=430.88
# t=55: resample:False, ESS (end of iter)=430.05
# t=86: resample:False, ESS (end of iter)=395.96
# t=56: resample:False, ESS (end of iter)=432.09
# t=57: resample:False, ESS (end of iter)=424.14
# t=58: resample:False, ESS (end of iter)=431.27
# t=22: resample:False, ESS (end of iter)=721.64
# t=87: resample:False, ESS (end of iter)=395.54
# t=59: resample:False, ESS (end of iter)=414.60
# t=60: resample:False, ESS (end of iter)=410.02
# t=61: resample:False, ESS (end of iter)=429.57
# t=23: resample:False, ESS (end of iter)=636.77
# t=88: resample:False, ESS (end of iter)=392.78
# t=62: resample:False, ESS (end of iter)=412.81
# t=63: resample:False, ESS (end of iter)=392.27
# t=24: resample:False, ESS (end of iter)=644.73
# t=64: resample:False, ESS (end of iter)=424.36
# t=65: resample:False, ESS (end of iter)=411.65
# t=25: resample:False, ESS (end of iter)=603.27
# t=66: resample:False, ESS (end of iter)=426.09
# t=89: resample:False, ESS (end of iter)=393.83
# t=67: resample:False, ESS (end of iter)=408.79
# t=26: resample:False, ESS (end of iter)=583.49
# t=68: resample:False, ESS (end of iter)=388.98
# t=90: resample:False, ESS (end of iter)=387.30t=27: resample:False, ESS (end of iter)=553.52
#
# t=69: resample:False, ESS (end of iter)=372.31
# t=28: resample:False, ESS (end of iter)=522.24
# t=70: resample:False, ESS (end of iter)=376.75
# t=29: resample:False, ESS (end of iter)=454.06
# t=91: resample:False, ESS (end of iter)=391.53
# t=30: resample:True, ESS (end of iter)=967.32
# t=71: resample:False, ESS (end of iter)=359.77
# t=31: resample:False, ESS (end of iter)=614.27
# t=92: resample:False, ESS (end of iter)=388.11
# t=5: resample:True, ESS (end of iter)=440.55
# t=72: resample:False, ESS (end of iter)=326.93
# t=32: resample:False, ESS (end of iter)=523.11
# t=6: resample:False, ESS (end of iter)=364.87
# t=93: resample:False, ESS (end of iter)=381.75
# t=7: resample:False, ESS (end of iter)=405.17
# t=33: resample:False, ESS (end of iter)=381.31
# t=73: resample:False, ESS (end of iter)=349.54
# t=8: resample:False, ESS (end of iter)=428.13
# t=34: resample:True, ESS (end of iter)=921.24
# t=9: resample:False, ESS (end of iter)=416.06
# t=94: resample:False, ESS (end of iter)=375.38
# t=5: resample:True, ESS (end of iter)=87.19
# t=10: resample:False, ESS (end of iter)=361.63
# t=6: resample:False, ESS (end of iter)=71.56
# t=35: resample:False, ESS (end of iter)=974.87
# t=74: resample:False, ESS (end of iter)=355.86
# t=7: resample:False, ESS (end of iter)=77.41
# t=11: resample:False, ESS (end of iter)=372.13
# t=8: resample:False, ESS (end of iter)=82.14
# t=95: resample:False, ESS (end of iter)=352.83
# t=9: resample:False, ESS (end of iter)=83.42
# t=36: resample:False, ESS (end of iter)=953.77
# t=12: resample:False, ESS (end of iter)=352.43
# t=10: resample:False, ESS (end of iter)=64.78
# t=11: resample:False, ESS (end of iter)=69.96
# t=75: resample:False, ESS (end of iter)=375.22t=13: resample:False, ESS (end of iter)=324.64
#
# t=37: resample:False, ESS (end of iter)=974.22
# t=12: resample:False, ESS (end of iter)=65.32
# t=96: resample:False, ESS (end of iter)=371.70
# t=14: resample:False, ESS (end of iter)=302.06
# t=13: resample:False, ESS (end of iter)=65.66
# t=14: resample:False, ESS (end of iter)=60.17
# t=38: resample:False, ESS (end of iter)=887.11
# t=15: resample:False, ESS (end of iter)=250.36
# t=15: resample:False, ESS (end of iter)=55.77
# t=76: resample:False, ESS (end of iter)=379.17
# t=16: resample:False, ESS (end of iter)=48.69
# t=97: resample:False, ESS (end of iter)=375.27
# t=39: resample:False, ESS (end of iter)=654.55
# t=16: resample:False, ESS (end of iter)=193.58
# t=17: resample:True, ESS (end of iter)=79.68
# t=18: resample:False, ESS (end of iter)=67.45
# t=17: resample:True, ESS (end of iter)=416.75
# t=40: resample:False, ESS (end of iter)=553.71
# t=19: resample:False, ESS (end of iter)=79.00
# t=77: resample:False, ESS (end of iter)=347.33
# t=20: resample:False, ESS (end of iter)=79.27
# t=98: resample:False, ESS (end of iter)=371.94
# t=18: resample:False, ESS (end of iter)=354.33
# t=21: resample:False, ESS (end of iter)=69.42
# t=41: resample:False, ESS (end of iter)=533.57
# t=22: resample:False, ESS (end of iter)=68.84
# t=19: resample:False, ESS (end of iter)=416.50
# t=23: resample:False, ESS (end of iter)=64.24
# t=42: resample:False, ESS (end of iter)=604.38
# t=78: resample:False, ESS (end of iter)=319.31
# t=24: resample:False, ESS (end of iter)=60.54
# t=99: resample:False, ESS (end of iter)=347.49
# t=20: resample:False, ESS (end of iter)=401.97
# t=43: resample:False, ESS (end of iter)=674.24
# t=25: resample:False, ESS (end of iter)=54.24
# t=44: resample:False, ESS (end of iter)=737.48
# t=79: resample:False, ESS (end of iter)=325.40
# t=21: resample:False, ESS (end of iter)=331.62
# t=45: resample:False, ESS (end of iter)=775.00
# t=26: resample:False, ESS (end of iter)=53.21
# t=46: resample:False, ESS (end of iter)=717.56
# t=80: resample:False, ESS (end of iter)=388.43
# t=27: resample:False, ESS (end of iter)=51.78
# t=22: resample:False, ESS (end of iter)=354.10
# t=47: resample:False, ESS (end of iter)=698.47
# t=48: resample:False, ESS (end of iter)=683.67
# t=28: resample:False, ESS (end of iter)=49.78
# t=81: resample:False, ESS (end of iter)=394.87
# t=49: resample:False, ESS (end of iter)=691.14
# t=29: resample:True, ESS (end of iter)=89.56
# t=23: resample:False, ESS (end of iter)=318.77
# t=30: resample:False, ESS (end of iter)=79.88
# t=82: resample:False, ESS (end of iter)=412.08
# t=50: resample:False, ESS (end of iter)=673.55
# t=31: resample:False, ESS (end of iter)=85.40
# t=83: resample:False, ESS (end of iter)=395.57
# t=24: resample:False, ESS (end of iter)=315.41
# t=32: resample:False, ESS (end of iter)=76.02
# t=84: resample:False, ESS (end of iter)=404.67
# t=33: resample:False, ESS (end of iter)=60.59
# t=51: resample:False, ESS (end of iter)=676.30
# t=85: resample:False, ESS (end of iter)=410.29
# t=34: resample:False, ESS (end of iter)=72.18
# t=86: resample:False, ESS (end of iter)=411.01
# t=35: resample:False, ESS (end of iter)=64.89
# t=87: resample:False, ESS (end of iter)=407.93
# t=52: resample:False, ESS (end of iter)=678.64
# t=36: resample:False, ESS (end of iter)=49.44
# t=88: resample:False, ESS (end of iter)=401.61
# t=89: resample:False, ESS (end of iter)=407.36
# t=37: resample:True, ESS (end of iter)=98.48
# t=90: resample:False, ESS (end of iter)=405.60
# t=53: resample:False, ESS (end of iter)=675.89
# t=38: resample:False, ESS (end of iter)=96.52
# t=39: resample:False, ESS (end of iter)=73.07
# t=54: resample:False, ESS (end of iter)=682.12
# t=91: resample:False, ESS (end of iter)=405.70
# t=40: resample:False, ESS (end of iter)=61.55
# t=41: resample:False, ESS (end of iter)=58.94
# t=92: resample:False, ESS (end of iter)=397.23
# t=42: resample:False, ESS (end of iter)=66.46
# t=55: resample:False, ESS (end of iter)=680.24
# t=43: resample:False, ESS (end of iter)=74.14
# t=25: resample:False, ESS (end of iter)=291.66
# t=44: resample:False, ESS (end of iter)=81.27
# t=45: resample:False, ESS (end of iter)=85.45
# t=46: resample:False, ESS (end of iter)=78.87
# t=93: resample:False, ESS (end of iter)=386.61
# t=47: resample:False, ESS (end of iter)=76.61
# t=48: resample:False, ESS (end of iter)=74.79
# t=26: resample:False, ESS (end of iter)=284.24
# t=49: resample:False, ESS (end of iter)=75.77
# t=56: resample:False, ESS (end of iter)=684.64
# t=50: resample:False, ESS (end of iter)=73.09
# t=51: resample:False, ESS (end of iter)=73.65
# t=94: resample:False, ESS (end of iter)=395.87
# t=52: resample:False, ESS (end of iter)=73.59
# t=53: resample:False, ESS (end of iter)=73.39
# t=54: resample:False, ESS (end of iter)=74.01
# t=55: resample:False, ESS (end of iter)=73.82
# t=56: resample:False, ESS (end of iter)=74.26
# t=57: resample:False, ESS (end of iter)=72.52
# t=27: resample:False, ESS (end of iter)=270.99
# t=58: resample:False, ESS (end of iter)=74.12
# t=95: resample:False, ESS (end of iter)=379.96
# t=59: resample:False, ESS (end of iter)=70.32
# t=60: resample:False, ESS (end of iter)=69.29
# t=61: resample:False, ESS (end of iter)=73.97
# t=62: resample:False, ESS (end of iter)=69.90
# t=63: resample:False, ESS (end of iter)=65.37
# t=28: resample:False, ESS (end of iter)=256.92
# t=96: resample:False, ESS (end of iter)=391.86
# t=64: resample:False, ESS (end of iter)=72.71
# t=65: resample:False, ESS (end of iter)=69.66
# t=66: resample:False, ESS (end of iter)=73.27
# t=67: resample:False, ESS (end of iter)=69.10
# t=68: resample:False, ESS (end of iter)=64.55
# t=69: resample:False, ESS (end of iter)=60.81
# t=29: resample:False, ESS (end of iter)=230.59
# t=70: resample:False, ESS (end of iter)=61.88
# t=57: resample:False, ESS (end of iter)=667.93
# t=71: resample:False, ESS (end of iter)=58.20
# t=72: resample:False, ESS (end of iter)=51.26
# t=97: resample:False, ESS (end of iter)=392.51
# t=73: resample:False, ESS (end of iter)=56.09
# t=58: resample:False, ESS (end of iter)=682.80
# t=74: resample:False, ESS (end of iter)=57.48
# t=75: resample:False, ESS (end of iter)=61.56
# t=59: resample:False, ESS (end of iter)=648.83
# t=76: resample:False, ESS (end of iter)=62.48
# t=77: resample:False, ESS (end of iter)=55.91
# t=78: resample:False, ESS (end of iter)=50.27
# t=60: resample:False, ESS (end of iter)=639.99
# t=98: resample:False, ESS (end of iter)=390.64
# t=79: resample:False, ESS (end of iter)=51.51
# t=30: resample:True, ESS (end of iter)=486.41
# t=80: resample:False, ESS (end of iter)=64.52
# t=61: resample:False, ESS (end of iter)=679.75
# t=81: resample:False, ESS (end of iter)=65.68
# t=82: resample:False, ESS (end of iter)=69.69
# t=83: resample:False, ESS (end of iter)=67.84
# t=62: resample:False, ESS (end of iter)=646.16
# t=99: resample:False, ESS (end of iter)=372.86
# t=84: resample:False, ESS (end of iter)=68.91
# t=85: resample:False, ESS (end of iter)=70.07
# t=86: resample:False, ESS (end of iter)=71.01
# t=87: resample:False, ESS (end of iter)=70.99
# t=88: resample:False, ESS (end of iter)=70.54
# t=89: resample:False, ESS (end of iter)=70.54
# t=63: resample:False, ESS (end of iter)=607.14
# t=90: resample:False, ESS (end of iter)=69.03
# t=91: resample:False, ESS (end of iter)=70.35
# t=92: resample:False, ESS (end of iter)=70.25
# t=93: resample:False, ESS (end of iter)=69.11
# t=94: resample:False, ESS (end of iter)=67.13
# t=95: resample:False, ESS (end of iter)=63.96
# t=96: resample:False, ESS (end of iter)=67.22
# t=64: resample:False, ESS (end of iter)=668.91
# t=97: resample:False, ESS (end of iter)=68.18
# t=98: resample:False, ESS (end of iter)=67.60
# t=99: resample:False, ESS (end of iter)=61.87
# t=65: resample:False, ESS (end of iter)=644.43
# t=66: resample:False, ESS (end of iter)=672.59
# t=67: resample:False, ESS (end of iter)=639.86
# t=68: resample:False, ESS (end of iter)=604.44
# t=31: resample:False, ESS (end of iter)=307.84
# t=32: resample:False, ESS (end of iter)=258.26
# t=33: resample:False, ESS (end of iter)=182.87
# t=34: resample:True, ESS (end of iter)=464.10
# t=35: resample:False, ESS (end of iter)=491.92
# t=36: resample:False, ESS (end of iter)=470.25
# t=37: resample:False, ESS (end of iter)=485.75
# t=69: resample:False, ESS (end of iter)=575.35
# t=38: resample:False, ESS (end of iter)=428.10
# t=39: resample:False, ESS (end of iter)=312.37
# t=40: resample:False, ESS (end of iter)=269.11
# t=41: resample:False, ESS (end of iter)=259.21t=70: resample:False, ESS (end of iter)=583.94
#
# t=42: resample:False, ESS (end of iter)=285.96
# t=71: resample:False, ESS (end of iter)=555.25
# t=43: resample:False, ESS (end of iter)=315.19
# t=72: resample:False, ESS (end of iter)=497.57
# t=44: resample:False, ESS (end of iter)=344.16
# t=73: resample:True, ESS (end of iter)=991.02
# t=45: resample:False, ESS (end of iter)=362.86
# t=46: resample:False, ESS (end of iter)=333.96
# t=47: resample:False, ESS (end of iter)=324.66
# t=48: resample:False, ESS (end of iter)=317.52
# t=74: resample:False, ESS (end of iter)=984.40
# t=49: resample:False, ESS (end of iter)=321.12
# t=50: resample:False, ESS (end of iter)=311.90
# t=51: resample:False, ESS (end of iter)=313.58
# t=52: resample:False, ESS (end of iter)=314.07
# t=53: resample:False, ESS (end of iter)=313.09
# t=54: resample:False, ESS (end of iter)=315.53
# t=75: resample:False, ESS (end of iter)=958.32
# t=55: resample:False, ESS (end of iter)=314.70
# t=56: resample:False, ESS (end of iter)=316.38
# t=57: resample:False, ESS (end of iter)=309.39
# t=58: resample:False, ESS (end of iter)=315.39
# t=59: resample:False, ESS (end of iter)=301.34
# t=76: resample:False, ESS (end of iter)=949.44
# t=60: resample:False, ESS (end of iter)=297.52
# t=61: resample:False, ESS (end of iter)=314.02
# t=62: resample:False, ESS (end of iter)=299.40
# t=63: resample:False, ESS (end of iter)=283.30
# t=64: resample:False, ESS (end of iter)=308.60
# t=65: resample:False, ESS (end of iter)=297.72
# t=77: resample:False, ESS (end of iter)=986.13
# t=66: resample:False, ESS (end of iter)=309.60
# t=67: resample:False, ESS (end of iter)=294.90
# t=68: resample:False, ESS (end of iter)=279.63
# t=69: resample:False, ESS (end of iter)=267.50
# t=78: resample:False, ESS (end of iter)=993.59
# t=70: resample:False, ESS (end of iter)=270.36
# t=79: resample:False, ESS (end of iter)=992.55
# t=71: resample:False, ESS (end of iter)=258.51
# t=72: resample:False, ESS (end of iter)=236.66
# t=80: resample:False, ESS (end of iter)=910.62
# t=73: resample:True, ESS (end of iter)=497.71
# t=81: resample:False, ESS (end of iter)=888.06
# t=74: resample:False, ESS (end of iter)=496.24
# t=75: resample:False, ESS (end of iter)=488.59
# t=82: resample:False, ESS (end of iter)=605.76
# t=83: resample:False, ESS (end of iter)=513.76
# t=76: resample:False, ESS (end of iter)=486.33
# t=84: resample:False, ESS (end of iter)=565.45
# t=85: resample:False, ESS (end of iter)=617.09
# t=77: resample:False, ESS (end of iter)=497.52
# t=86: resample:False, ESS (end of iter)=681.10
# t=87: resample:False, ESS (end of iter)=710.91
# t=78: resample:False, ESS (end of iter)=497.61
# t=88: resample:False, ESS (end of iter)=743.07
# t=79: resample:False, ESS (end of iter)=498.13
# t=89: resample:False, ESS (end of iter)=691.48
# t=80: resample:False, ESS (end of iter)=474.35
# t=90: resample:False, ESS (end of iter)=632.04
# t=91: resample:False, ESS (end of iter)=680.96
# t=81: resample:False, ESS (end of iter)=466.23
# t=92: resample:False, ESS (end of iter)=732.14
# t=93: resample:False, ESS (end of iter)=754.33
# t=0: resample:False, ESS (end of iter)=500.00
# t=1: resample:False, ESS (end of iter)=407.42
# t=2: resample:False, ESS (end of iter)=419.07
# t=3: resample:False, ESS (end of iter)=254.82
# t=82: resample:False, ESS (end of iter)=335.11
# t=4: resample:False, ESS (end of iter)=144.82
# t=5: resample:True, ESS (end of iter)=439.96
# t=83: resample:False, ESS (end of iter)=289.02
# t=94: resample:False, ESS (end of iter)=605.37
# t=6: resample:False, ESS (end of iter)=366.53
# t=84: resample:False, ESS (end of iter)=314.94
# t=7: resample:False, ESS (end of iter)=406.99
# t=85: resample:False, ESS (end of iter)=341.84
# t=8: resample:False, ESS (end of iter)=427.38
# t=86: resample:False, ESS (end of iter)=374.51
# t=9: resample:False, ESS (end of iter)=415.17
# t=87: resample:False, ESS (end of iter)=389.64
# t=10: resample:False, ESS (end of iter)=367.14
# t=11: resample:False, ESS (end of iter)=378.63
# t=95: resample:False, ESS (end of iter)=531.59
# t=88: resample:False, ESS (end of iter)=405.67
# t=12: resample:False, ESS (end of iter)=358.58
# t=89: resample:False, ESS (end of iter)=380.56
# t=13: resample:False, ESS (end of iter)=331.56
# t=90: resample:False, ESS (end of iter)=348.17
# t=14: resample:False, ESS (end of iter)=307.16
# t=91: resample:False, ESS (end of iter)=375.55
# t=96: resample:False, ESS (end of iter)=597.62
# t=15: resample:False, ESS (end of iter)=258.12
# t=92: resample:False, ESS (end of iter)=401.30
# t=16: resample:False, ESS (end of iter)=199.93
# t=93: resample:False, ESS (end of iter)=411.69
# t=94: resample:False, ESS (end of iter)=336.29
# t=97: resample:False, ESS (end of iter)=618.33
# t=95: resample:False, ESS (end of iter)=296.11
# t=96: resample:False, ESS (end of iter)=332.31
# t=97: resample:False, ESS (end of iter)=343.50
# t=98: resample:False, ESS (end of iter)=337.42
# t=98: resample:False, ESS (end of iter)=605.98t=99: resample:False, ESS (end of iter)=292.32
#
# t=99: resample:False, ESS (end of iter)=519.99
# t=0: resample:False, ESS (end of iter)=1000.00
# t=17: resample:True, ESS (end of iter)=422.06
# t=1: resample:False, ESS (end of iter)=831.73
# t=18: resample:False, ESS (end of iter)=368.51
# t=2: resample:False, ESS (end of iter)=851.00
# t=19: resample:False, ESS (end of iter)=418.05
# t=3: resample:False, ESS (end of iter)=529.02
# t=20: resample:False, ESS (end of iter)=398.81
# t=4: resample:False, ESS (end of iter)=307.72
# t=21: resample:False, ESS (end of iter)=322.22
# t=5: resample:True, ESS (end of iter)=881.59
# t=22: resample:False, ESS (end of iter)=349.98
# t=23: resample:False, ESS (end of iter)=312.47
# t=6: resample:False, ESS (end of iter)=731.82
# t=24: resample:False, ESS (end of iter)=309.15
# t=7: resample:False, ESS (end of iter)=813.09
# t=25: resample:False, ESS (end of iter)=287.42
# t=8: resample:False, ESS (end of iter)=854.24
# t=26: resample:False, ESS (end of iter)=276.40
# t=9: resample:False, ESS (end of iter)=835.75
# t=27: resample:False, ESS (end of iter)=262.33
# t=10: resample:False, ESS (end of iter)=725.91
# t=28: resample:False, ESS (end of iter)=248.01
# t=11: resample:False, ESS (end of iter)=749.63
# t=29: resample:True, ESS (end of iter)=425.93
# t=12: resample:False, ESS (end of iter)=710.69t=30: resample:False, ESS (end of iter)=364.49
#
# t=13: resample:False, ESS (end of iter)=672.75
# t=31: resample:False, ESS (end of iter)=437.81
# t=14: resample:False, ESS (end of iter)=629.08
# t=32: resample:False, ESS (end of iter)=401.05
# t=15: resample:False, ESS (end of iter)=546.27
# t=33: resample:False, ESS (end of iter)=328.03
# t=16: resample:False, ESS (end of iter)=426.95
# t=17: resample:True, ESS (end of iter)=831.08
# t=34: resample:False, ESS (end of iter)=388.59
# t=18: resample:False, ESS (end of iter)=720.49
# t=35: resample:False, ESS (end of iter)=356.03
# t=19: resample:False, ESS (end of iter)=826.82
# t=4: resample:True, ESS (end of iter)=79.87
# t=36: resample:False, ESS (end of iter)=272.71
# t=20: resample:False, ESS (end of iter)=789.36
# t=5: resample:False, ESS (end of iter)=56.29
# t=37: resample:False, ESS (end of iter)=300.13
# t=6: resample:False, ESS (end of iter)=43.25
# t=21: resample:False, ESS (end of iter)=617.29
# t=7: resample:True, ESS (end of iter)=92.69
# t=22: resample:False, ESS (end of iter)=689.88
# t=38: resample:False, ESS (end of iter)=234.53
# t=23: resample:False, ESS (end of iter)=611.97
# t=8: resample:False, ESS (end of iter)=75.55
# t=39: resample:True, ESS (end of iter)=420.46
# t=9: resample:False, ESS (end of iter)=55.50
# t=24: resample:False, ESS (end of iter)=610.43
# t=40: resample:False, ESS (end of iter)=364.67
# t=25: resample:False, ESS (end of iter)=568.02
# t=10: resample:False, ESS (end of iter)=77.84
# t=41: resample:False, ESS (end of iter)=352.29
# t=11: resample:False, ESS (end of iter)=64.06
# t=26: resample:False, ESS (end of iter)=547.39
# t=42: resample:False, ESS (end of iter)=391.95
# t=12: resample:False, ESS (end of iter)=60.03
# t=27: resample:False, ESS (end of iter)=521.51
# t=13: resample:False, ESS (end of iter)=46.17
# t=43: resample:False, ESS (end of iter)=428.85
# t=28: resample:False, ESS (end of iter)=495.06
# t=14: resample:True, ESS (end of iter)=98.47
# t=15: resample:False, ESS (end of iter)=82.73
# t=29: resample:True, ESS (end of iter)=858.47
# t=44: resample:False, ESS (end of iter)=457.59
# t=16: resample:False, ESS (end of iter)=58.95
# t=30: resample:False, ESS (end of iter)=741.24
# t=17: resample:False, ESS (end of iter)=74.34
# t=45: resample:False, ESS (end of iter)=471.03
# t=31: resample:False, ESS (end of iter)=854.21
# t=18: resample:False, ESS (end of iter)=74.05
# t=46: resample:False, ESS (end of iter)=449.06
# t=32: resample:False, ESS (end of iter)=770.15
# t=19: resample:False, ESS (end of iter)=60.78
# t=33: resample:False, ESS (end of iter)=619.11
# t=47: resample:False, ESS (end of iter)=440.32
# t=20: resample:False, ESS (end of iter)=47.10
# t=34: resample:False, ESS (end of iter)=740.37
# t=21: resample:True, ESS (end of iter)=84.19
# t=35: resample:False, ESS (end of iter)=671.35
# t=48: resample:False, ESS (end of iter)=433.12
# t=36: resample:False, ESS (end of iter)=509.09
# t=0: resample:False, ESS (end of iter)=100.00
# t=1: resample:False, ESS (end of iter)=85.91
# t=49: resample:False, ESS (end of iter)=436.78
# t=22: resample:False, ESS (end of iter)=94.63
# t=2: resample:False, ESS (end of iter)=87.34
# t=3: resample:False, ESS (end of iter)=56.51
# t=23: resample:False, ESS (end of iter)=88.31
# t=4: resample:False, ESS (end of iter)=36.78
# t=24: resample:False, ESS (end of iter)=87.20
# t=5: resample:True, ESS (end of iter)=89.14
# t=50: resample:False, ESS (end of iter)=427.26
# t=6: resample:False, ESS (end of iter)=75.64
# t=25: resample:False, ESS (end of iter)=76.18
# t=7: resample:False, ESS (end of iter)=81.15
# t=26: resample:False, ESS (end of iter)=77.76
# t=8: resample:False, ESS (end of iter)=85.43
# t=27: resample:False, ESS (end of iter)=77.78
# t=9: resample:False, ESS (end of iter)=84.85
# t=51: resample:False, ESS (end of iter)=429.04
# t=10: resample:False, ESS (end of iter)=71.00
# t=28: resample:False, ESS (end of iter)=75.22
# t=11: resample:False, ESS (end of iter)=76.32
# t=29: resample:False, ESS (end of iter)=68.98
# t=12: resample:False, ESS (end of iter)=72.65
# t=30: resample:False, ESS (end of iter)=62.68
# t=13: resample:False, ESS (end of iter)=72.61
# t=52: resample:False, ESS (end of iter)=429.74
# t=31: resample:False, ESS (end of iter)=63.78
# t=14: resample:False, ESS (end of iter)=68.44
# t=32: resample:False, ESS (end of iter)=59.72
# t=15: resample:False, ESS (end of iter)=61.74
# t=33: resample:False, ESS (end of iter)=52.54
# t=16: resample:False, ESS (end of iter)=49.70
# t=34: resample:False, ESS (end of iter)=56.98
# t=17: resample:True, ESS (end of iter)=81.61
# t=35: resample:False, ESS (end of iter)=53.45
# t=18: resample:False, ESS (end of iter)=70.75
# t=36: resample:False, ESS (end of iter)=45.68
# t=53: resample:False, ESS (end of iter)=428.61
# t=19: resample:False, ESS (end of iter)=81.75
# t=37: resample:True, ESS (end of iter)=98.61
# t=20: resample:False, ESS (end of iter)=78.44
# t=38: resample:False, ESS (end of iter)=97.61
# t=21: resample:False, ESS (end of iter)=63.79
# t=39: resample:False, ESS (end of iter)=78.25
# t=22: resample:False, ESS (end of iter)=66.65
# t=40: resample:False, ESS (end of iter)=67.65
# t=54: resample:False, ESS (end of iter)=431.53
# t=23: resample:False, ESS (end of iter)=58.77
# t=41: resample:False, ESS (end of iter)=65.26
# t=24: resample:False, ESS (end of iter)=58.25
# t=42: resample:False, ESS (end of iter)=72.78
# t=25: resample:False, ESS (end of iter)=55.54
# t=43: resample:False, ESS (end of iter)=79.75
# t=26: resample:False, ESS (end of iter)=52.11
# t=44: resample:False, ESS (end of iter)=85.62
# t=55: resample:False, ESS (end of iter)=430.73
# t=27: resample:False, ESS (end of iter)=48.56
# t=45: resample:False, ESS (end of iter)=88.77
# t=46: resample:False, ESS (end of iter)=83.99
# t=28: resample:True, ESS (end of iter)=98.52
# t=47: resample:False, ESS (end of iter)=82.33
# t=29: resample:False, ESS (end of iter)=78.84
# t=48: resample:False, ESS (end of iter)=80.96
# t=30: resample:False, ESS (end of iter)=65.76
# t=56: resample:False, ESS (end of iter)=432.78
# t=49: resample:False, ESS (end of iter)=81.69
# t=31: resample:False, ESS (end of iter)=87.04
# t=50: resample:False, ESS (end of iter)=79.91
# t=32: resample:False, ESS (end of iter)=82.64
# t=51: resample:False, ESS (end of iter)=80.19
# t=33: resample:False, ESS (end of iter)=72.84
# t=52: resample:False, ESS (end of iter)=80.44
# t=34: resample:False, ESS (end of iter)=79.73
# t=57: resample:False, ESS (end of iter)=424.95t=53: resample:False, ESS (end of iter)=80.19
#
# t=35: resample:False, ESS (end of iter)=75.25
# t=54: resample:False, ESS (end of iter)=80.79
# t=36: resample:False, ESS (end of iter)=61.52
# t=55: resample:False, ESS (end of iter)=80.59
# t=37: resample:False, ESS (end of iter)=65.73
# t=56: resample:False, ESS (end of iter)=81.03
# t=38: resample:False, ESS (end of iter)=52.95
# t=57: resample:False, ESS (end of iter)=79.34
# t=58: resample:False, ESS (end of iter)=431.99
# t=39: resample:False, ESS (end of iter)=34.32
# t=58: resample:False, ESS (end of iter)=80.86
# t=59: resample:False, ESS (end of iter)=77.27
# t=60: resample:False, ESS (end of iter)=76.34
# t=61: resample:False, ESS (end of iter)=80.47
# t=62: resample:False, ESS (end of iter)=77.08
# t=63: resample:False, ESS (end of iter)=73.20
# t=64: resample:False, ESS (end of iter)=79.25
# t=37: resample:False, ESS (end of iter)=559.16
# t=65: resample:False, ESS (end of iter)=76.85
# t=66: resample:False, ESS (end of iter)=79.66
# t=67: resample:False, ESS (end of iter)=76.51
# t=38: resample:False, ESS (end of iter)=438.43
# t=68: resample:False, ESS (end of iter)=72.97
# t=69: resample:False, ESS (end of iter)=69.94
# t=70: resample:False, ESS (end of iter)=70.86
# t=71: resample:False, ESS (end of iter)=67.56
# t=39: resample:True, ESS (end of iter)=851.26
# t=59: resample:False, ESS (end of iter)=415.26
# t=72: resample:False, ESS (end of iter)=60.65
# t=73: resample:False, ESS (end of iter)=65.82
# t=40: resample:False, ESS (end of iter)=747.47
# t=74: resample:False, ESS (end of iter)=67.24
# t=75: resample:False, ESS (end of iter)=71.11
# t=76: resample:False, ESS (end of iter)=71.91
# t=41: resample:False, ESS (end of iter)=724.03
# t=60: resample:False, ESS (end of iter)=410.63
# t=77: resample:False, ESS (end of iter)=65.79
# t=78: resample:False, ESS (end of iter)=60.08
# t=42: resample:False, ESS (end of iter)=797.73
# t=79: resample:False, ESS (end of iter)=61.27
# t=80: resample:False, ESS (end of iter)=72.99
# t=61: resample:False, ESS (end of iter)=430.85
# t=81: resample:False, ESS (end of iter)=73.97
# t=43: resample:False, ESS (end of iter)=864.81
# ...
# t=34: resample:False, ESS (end of iter)=52.86
# t=41: resample:False, ESS (end of iter)=696.63
# t=2: resample:False, ESS (end of iter)=857.60
# t=35: resample:False, ESS (end of iter)=51.06
# t=13: resample:False, ESS (end of iter)=280.62
# t=84: resample:False, ESS (end of iter)=730.92
# t=36: resample:False, ESS (end of iter)=45.56
# t=42: resample:False, ESS (end of iter)=784.21
# t=37: resample:True, ESS (end of iter)=98.20
# t=14: resample:False, ESS (end of iter)=261.35
# t=38: resample:False, ESS (end of iter)=96.40
# t=84: resample:False, ESS (end of iter)=377.55
# t=43: resample:False, ESS (end of iter)=862.45
# t=39: resample:False, ESS (end of iter)=69.08
# t=85: resample:False, ESS (end of iter)=737.95
# t=15: resample:False, ESS (end of iter)=195.08
# t=3: resample:False, ESS (end of iter)=505.59
# t=40: resample:False, ESS (end of iter)=56.23
# t=41: resample:False, ESS (end of iter)=53.73
# t=16: resample:True, ESS (end of iter)=424.09
# t=44: resample:False, ESS (end of iter)=921.09
# t=42: resample:False, ESS (end of iter)=62.62
# t=43: resample:False, ESS (end of iter)=71.46
# t=17: resample:False, ESS (end of iter)=461.84
# t=45: resample:False, ESS (end of iter)=947.06
# t=85: resample:False, ESS (end of iter)=398.56
# t=44: resample:False, ESS (end of iter)=79.58
# t=45: resample:False, ESS (end of iter)=84.28
# t=4: resample:False, ESS (end of iter)=271.72
# t=86: resample:False, ESS (end of iter)=738.21
# t=18: resample:False, ESS (end of iter)=418.81
# t=46: resample:False, ESS (end of iter)=77.01
# t=46: resample:False, ESS (end of iter)=905.18
# t=47: resample:False, ESS (end of iter)=74.50
# t=19: resample:False, ESS (end of iter)=410.21
# t=48: resample:False, ESS (end of iter)=72.64
# t=49: resample:False, ESS (end of iter)=73.65t=47: resample:False, ESS (end of iter)=888.13
#
# t=20: resample:False, ESS (end of iter)=347.51
# t=50: resample:False, ESS (end of iter)=71.07
# t=86: resample:False, ESS (end of iter)=420.19
# t=51: resample:False, ESS (end of iter)=71.53
# t=52: resample:False, ESS (end of iter)=71.70
# t=21: resample:False, ESS (end of iter)=250.36
# t=53: resample:False, ESS (end of iter)=71.36
# t=5: resample:True, ESS (end of iter)=877.20
# t=54: resample:False, ESS (end of iter)=72.13
# t=22: resample:False, ESS (end of iter)=303.93
# t=55: resample:False, ESS (end of iter)=71.89
# t=56: resample:False, ESS (end of iter)=72.41
# t=87: resample:False, ESS (end of iter)=732.32
# t=23: resample:False, ESS (end of iter)=257.75
# t=57: resample:False, ESS (end of iter)=70.37
# t=6: resample:False, ESS (end of iter)=719.90
# t=48: resample:False, ESS (end of iter)=874.11t=58: resample:False, ESS (end of iter)=72.18
#
# t=87: resample:False, ESS (end of iter)=427.62
# t=59: resample:False, ESS (end of iter)=68.11
# t=24: resample:False, ESS (end of iter)=266.28
# t=60: resample:False, ESS (end of iter)=67.05
# t=7: resample:False, ESS (end of iter)=816.02
# t=61: resample:False, ESS (end of iter)=71.80
# t=25: resample:False, ESS (end of iter)=256.76
# t=62: resample:False, ESS (end of iter)=67.84
# t=63: resample:False, ESS (end of iter)=63.31
# t=8: resample:False, ESS (end of iter)=855.50
# t=26: resample:False, ESS (end of iter)=242.74
# t=64: resample:False, ESS (end of iter)=70.51
# t=65: resample:False, ESS (end of iter)=67.56
# t=9: resample:False, ESS (end of iter)=824.01
# t=88: resample:False, ESS (end of iter)=433.66
# t=66: resample:False, ESS (end of iter)=71.00
# t=88: resample:False, ESS (end of iter)=722.35
# t=27: resample:True, ESS (end of iter)=476.81
# t=67: resample:False, ESS (end of iter)=67.02
# t=49: resample:False, ESS (end of iter)=880.94
# t=68: resample:False, ESS (end of iter)=62.67
# t=10: resample:False, ESS (end of iter)=732.08
# t=28: resample:False, ESS (end of iter)=450.21
# t=69: resample:False, ESS (end of iter)=59.19
# t=70: resample:False, ESS (end of iter)=60.19
# t=29: resample:False, ESS (end of iter)=318.57
# t=71: resample:False, ESS (end of iter)=56.92
# t=11: resample:False, ESS (end of iter)=746.11
# t=72: resample:False, ESS (end of iter)=50.24
# t=89: resample:False, ESS (end of iter)=421.00
# t=30: resample:False, ESS (end of iter)=260.18
# t=73: resample:False, ESS (end of iter)=55.21
# t=74: resample:False, ESS (end of iter)=56.72
# t=12: resample:False, ESS (end of iter)=704.67
# t=31: resample:False, ESS (end of iter)=450.00t=75: resample:False, ESS (end of iter)=60.72
#
# t=50: resample:False, ESS (end of iter)=865.42
# t=76: resample:False, ESS (end of iter)=61.61
# t=89: resample:False, ESS (end of iter)=730.91
# t=32: resample:False, ESS (end of iter)=432.49
# t=77: resample:False, ESS (end of iter)=55.66
# t=13: resample:False, ESS (end of iter)=650.06
# t=78: resample:False, ESS (end of iter)=50.79
# t=33: resample:False, ESS (end of iter)=389.06
# t=79: resample:False, ESS (end of iter)=51.92
# t=90: resample:False, ESS (end of iter)=401.90
# t=80: resample:False, ESS (end of iter)=63.64
# t=34: resample:False, ESS (end of iter)=415.28t=14: resample:False, ESS (end of iter)=604.24
#
# t=81: resample:False, ESS (end of iter)=64.99
# t=82: resample:False, ESS (end of iter)=77.41
# t=35: resample:False, ESS (end of iter)=394.65
# t=83: resample:False, ESS (end of iter)=77.73
# t=51: resample:False, ESS (end of iter)=867.10
# t=15: resample:False, ESS (end of iter)=508.77
# t=84: resample:False, ESS (end of iter)=77.45
# t=36: resample:False, ESS (end of iter)=340.59
# t=85: resample:False, ESS (end of iter)=76.67
# t=37: resample:False, ESS (end of iter)=354.47
# t=86: resample:False, ESS (end of iter)=74.33
# t=90: resample:False, ESS (end of iter)=728.88
# t=91: resample:False, ESS (end of iter)=416.54
# t=87: resample:False, ESS (end of iter)=72.75
# t=16: resample:False, ESS (end of iter)=395.61
# t=38: resample:False, ESS (end of iter)=309.69
# t=88: resample:False, ESS (end of iter)=70.72
# t=89: resample:False, ESS (end of iter)=73.10
# t=39: resample:False, ESS (end of iter)=240.71
# t=90: resample:False, ESS (end of iter)=74.45
# t=52: resample:False, ESS (end of iter)=870.37
# t=17: resample:True, ESS (end of iter)=844.23
# t=40: resample:True, ESS (end of iter)=486.93
# t=91: resample:False, ESS (end of iter)=72.50
# t=92: resample:False, ESS (end of iter)=69.41
# t=92: resample:False, ESS (end of iter)=426.16
# t=93: resample:False, ESS (end of iter)=67.22
# t=41: resample:False, ESS (end of iter)=480.78
# t=94: resample:False, ESS (end of iter)=72.97
# t=95: resample:False, ESS (end of iter)=72.79
# t=96: resample:False, ESS (end of iter)=72.04
# t=91: resample:False, ESS (end of iter)=727.27
# t=53: resample:False, ESS (end of iter)=867.38
# t=93: resample:False, ESS (end of iter)=426.99
# t=18: resample:False, ESS (end of iter)=723.81
# t=42: resample:False, ESS (end of iter)=495.48
# t=97: resample:False, ESS (end of iter)=71.11
# t=43: resample:False, ESS (end of iter)=497.60
# t=98: resample:False, ESS (end of iter)=71.09
# t=54: resample:False, ESS (end of iter)=874.26t=99: resample:False, ESS (end of iter)=71.61
#
# t=92: resample:False, ESS (end of iter)=710.36
# t=44: resample:False, ESS (end of iter)=485.92
# t=94: resample:False, ESS (end of iter)=386.79
# t=45: resample:False, ESS (end of iter)=470.25
# t=46: resample:False, ESS (end of iter)=490.53
# t=19: resample:False, ESS (end of iter)=841.86
# t=47: resample:False, ESS (end of iter)=493.59
# t=55: resample:False, ESS (end of iter)=872.46
# t=48: resample:False, ESS (end of iter)=494.74
# t=95: resample:False, ESS (end of iter)=356.00
# t=49: resample:False, ESS (end of iter)=494.24
# t=93: resample:False, ESS (end of iter)=692.26
# t=50: resample:False, ESS (end of iter)=492.82
# t=20: resample:False, ESS (end of iter)=810.60
# t=51: resample:False, ESS (end of iter)=494.48
# t=52: resample:False, ESS (end of iter)=492.48
# t=56: resample:False, ESS (end of iter)=877.09
# t=96: resample:False, ESS (end of iter)=382.01
# t=53: resample:False, ESS (end of iter)=493.48
# t=21: resample:False, ESS (end of iter)=655.39
# t=54: resample:False, ESS (end of iter)=491.73
# t=94: resample:False, ESS (end of iter)=712.46
# t=55: resample:False, ESS (end of iter)=492.09
# t=22: resample:False, ESS (end of iter)=717.33
# t=97: resample:False, ESS (end of iter)=388.56
# t=56: resample:False, ESS (end of iter)=491.07
# t=57: resample:False, ESS (end of iter)=493.43
# t=57: resample:False, ESS (end of iter)=859.87
# t=23: resample:False, ESS (end of iter)=642.31
# t=58: resample:False, ESS (end of iter)=491.29
# t=98: resample:False, ESS (end of iter)=383.64t=59: resample:False, ESS (end of iter)=493.95
#
# t=95: resample:False, ESS (end of iter)=683.48
# t=24: resample:False, ESS (end of iter)=636.50
# t=60: resample:False, ESS (end of iter)=493.70
# t=61: resample:False, ESS (end of iter)=491.17
# t=58: resample:False, ESS (end of iter)=875.68
# t=99: resample:False, ESS (end of iter)=350.58
# t=96: resample:False, ESS (end of iter)=705.19
# t=62: resample:False, ESS (end of iter)=493.11
# t=25: resample:False, ESS (end of iter)=577.95
# t=63: resample:False, ESS (end of iter)=490.35
# t=97: resample:False, ESS (end of iter)=706.91
# t=64: resample:False, ESS (end of iter)=491.44
# t=59: resample:False, ESS (end of iter)=838.82
# t=26: resample:False, ESS (end of iter)=563.73
# t=65: resample:False, ESS (end of iter)=492.02
# t=98: resample:False, ESS (end of iter)=702.45
# t=66: resample:False, ESS (end of iter)=490.16
# t=27: resample:False, ESS (end of iter)=542.37
# t=67: resample:False, ESS (end of iter)=491.06
# t=60: resample:False, ESS (end of iter)=828.80
# t=68: resample:False, ESS (end of iter)=487.74
# t=28: resample:False, ESS (end of iter)=516.66
# t=69: resample:False, ESS (end of iter)=482.13
# t=61: resample:False, ESS (end of iter)=873.11
# t=99: resample:False, ESS (end of iter)=665.04
# t=70: resample:False, ESS (end of iter)=483.51
# t=62: resample:False, ESS (end of iter)=836.43
# t=29: resample:False, ESS (end of iter)=470.06
# t=71: resample:False, ESS (end of iter)=476.27
# t=63: resample:False, ESS (end of iter)=790.22
# t=72: resample:False, ESS (end of iter)=456.04
# t=73: resample:False, ESS (end of iter)=470.51
# t=64: resample:False, ESS (end of iter)=862.52
# t=74: resample:False, ESS (end of iter)=473.57
# t=65: resample:False, ESS (end of iter)=835.40
# t=30: resample:True, ESS (end of iter)=970.18
# t=75: resample:False, ESS (end of iter)=480.85
# t=66: resample:False, ESS (end of iter)=867.24
# t=76: resample:False, ESS (end of iter)=481.44
# t=77: resample:False, ESS (end of iter)=468.62
# t=67: resample:False, ESS (end of iter)=831.22
# t=78: resample:False, ESS (end of iter)=450.11
# t=68: resample:False, ESS (end of iter)=788.69
# t=79: resample:False, ESS (end of iter)=454.40
# t=31: resample:False, ESS (end of iter)=613.07
# t=80: resample:False, ESS (end of iter)=477.15
# t=69: resample:False, ESS (end of iter)=751.82
# t=81: resample:False, ESS (end of iter)=475.16
# t=70: resample:False, ESS (end of iter)=763.02
# t=82: resample:False, ESS (end of iter)=401.08
# t=32: resample:False, ESS (end of iter)=522.59
# t=83: resample:False, ESS (end of iter)=362.43
# t=71: resample:False, ESS (end of iter)=725.73
# t=84: resample:False, ESS (end of iter)=383.91
# t=85: resample:False, ESS (end of iter)=402.77
# t=72: resample:False, ESS (end of iter)=649.79
# t=86: resample:False, ESS (end of iter)=422.53
# t=33: resample:False, ESS (end of iter)=379.07
# t=87: resample:False, ESS (end of iter)=429.98
# t=73: resample:False, ESS (end of iter)=704.52
# t=88: resample:False, ESS (end of iter)=436.60
# t=89: resample:False, ESS (end of iter)=423.58
# t=74: resample:False, ESS (end of iter)=720.70
# t=90: resample:False, ESS (end of iter)=404.03
# t=34: resample:True, ESS (end of iter)=930.05
# t=75: resample:False, ESS (end of iter)=765.31
# t=91: resample:False, ESS (end of iter)=418.69
# t=92: resample:False, ESS (end of iter)=429.73
# t=76: resample:False, ESS (end of iter)=775.06
# t=93: resample:False, ESS (end of iter)=432.18
# t=35: resample:False, ESS (end of iter)=980.83
# t=77: resample:False, ESS (end of iter)=705.97
# t=94: resample:False, ESS (end of iter)=386.73
# t=95: resample:False, ESS (end of iter)=356.89
# t=36: resample:False, ESS (end of iter)=948.03
# t=78: resample:False, ESS (end of iter)=642.60
# t=96: resample:False, ESS (end of iter)=382.66
# t=37: resample:False, ESS (end of iter)=973.38
# t=97: resample:False, ESS (end of iter)=389.71
# t=79: resample:False, ESS (end of iter)=657.90
# t=38: resample:False, ESS (end of iter)=871.90
# t=98: resample:False, ESS (end of iter)=384.37
# t=80: resample:False, ESS (end of iter)=795.17
# t=99: resample:False, ESS (end of iter)=348.79
# t=39: resample:False, ESS (end of iter)=615.38
# t=81: resample:False, ESS (end of iter)=807.31
# t=40: resample:False, ESS (end of iter)=509.12
# t=41: resample:False, ESS (end of iter)=486.78
# t=82: resample:False, ESS (end of iter)=812.69
# t=42: resample:True, ESS (end of iter)=982.66
# t=83: resample:False, ESS (end of iter)=770.68
# t=43: resample:False, ESS (end of iter)=928.53
# t=84: resample:False, ESS (end of iter)=793.02
# t=44: resample:False, ESS (end of iter)=843.96
# t=85: resample:False, ESS (end of iter)=808.42
# t=45: resample:False, ESS (end of iter)=774.03
# t=86: resample:False, ESS (end of iter)=816.91
# t=46: resample:False, ESS (end of iter)=876.17
# t=87: resample:False, ESS (end of iter)=814.82
# t=47: resample:False, ESS (end of iter)=902.41
# t=88: resample:False, ESS (end of iter)=807.14
# t=48: resample:False, ESS (end of iter)=919.76
# t=89: resample:False, ESS (end of iter)=809.76
# t=49: resample:False, ESS (end of iter)=910.94
# t=90: resample:False, ESS (end of iter)=798.21
# t=50: resample:False, ESS (end of iter)=925.97
# t=51: resample:False, ESS (end of iter)=926.43
# t=91: resample:False, ESS (end of iter)=802.61
# t=52: resample:False, ESS (end of iter)=920.92
# t=53: resample:False, ESS (end of iter)=925.03
# t=92: resample:False, ESS (end of iter)=792.96
# t=54: resample:False, ESS (end of iter)=916.45
# t=93: resample:False, ESS (end of iter)=776.88
# t=55: resample:False, ESS (end of iter)=918.82
# t=56: resample:False, ESS (end of iter)=913.20
# t=94: resample:False, ESS (end of iter)=773.27
# t=57: resample:False, ESS (end of iter)=931.76
# t=95: resample:False, ESS (end of iter)=734.30
# t=58: resample:False, ESS (end of iter)=915.57
# t=59: resample:False, ESS (end of iter)=948.25
# t=96: resample:False, ESS (end of iter)=764.50
# t=60: resample:False, ESS (end of iter)=954.68
# t=97: resample:False, ESS (end of iter)=768.39
# t=61: resample:False, ESS (end of iter)=918.51
# t=98: resample:False, ESS (end of iter)=762.54
# t=62: resample:False, ESS (end of iter)=949.35
# t=99: resample:False, ESS (end of iter)=719.04
# t=63: resample:False, ESS (end of iter)=972.07
# t=64: resample:False, ESS (end of iter)=927.48
# t=65: resample:False, ESS (end of iter)=949.10
# t=66: resample:False, ESS (end of iter)=922.10
# t=67: resample:False, ESS (end of iter)=951.35
# t=68: resample:False, ESS (end of iter)=970.76
# t=69: resample:False, ESS (end of iter)=978.05
# t=70: resample:False, ESS (end of iter)=975.93
# t=71: resample:False, ESS (end of iter)=977.94
# t=72: resample:False, ESS (end of iter)=963.47
# t=73: resample:False, ESS (end of iter)=974.66
# t=74: resample:False, ESS (end of iter)=974.77
# t=75: resample:False, ESS (end of iter)=969.14
# t=76: resample:False, ESS (end of iter)=965.16
# t=77: resample:False, ESS (end of iter)=970.27
# t=78: resample:False, ESS (end of iter)=952.85
# t=79: resample:False, ESS (end of iter)=957.01
# t=80: resample:False, ESS (end of iter)=939.18
# t=81: resample:False, ESS (end of iter)=924.34
# t=82: resample:False, ESS (end of iter)=683.00
# t=83: resample:False, ESS (end of iter)=592.06
# t=84: resample:False, ESS (end of iter)=644.86
# t=85: resample:False, ESS (end of iter)=696.52
# t=86: resample:False, ESS (end of iter)=758.18
# t=87: resample:False, ESS (end of iter)=784.79
# t=88: resample:False, ESS (end of iter)=811.77
# t=89: resample:False, ESS (end of iter)=766.77
# t=90: resample:False, ESS (end of iter)=710.36
# t=91: resample:False, ESS (end of iter)=757.19
# t=92: resample:False, ESS (end of iter)=800.85
# t=93: resample:False, ESS (end of iter)=817.16
# t=94: resample:False, ESS (end of iter)=681.96
# t=95: resample:False, ESS (end of iter)=605.74
# t=96: resample:False, ESS (end of iter)=677.07
# t=97: resample:False, ESS (end of iter)=699.23
# t=98: resample:False, ESS (end of iter)=686.55
# t=99: resample:False, ESS (end of iter)=595.36

# %%
print(alg_parallel[0]['output'].W)
# Out:
# [1.56454008e-02 2.82828991e-02 1.40186726e-02 9.99767328e-03
#  6.82819070e-03 1.46436410e-02 2.12460874e-02 1.00631795e-02
#  2.17572502e-02 1.46004700e-02 6.56696454e-03 5.23788954e-03
#  4.67758158e-03 7.24029718e-03 9.61460558e-03 1.69663248e-02
#  4.31720337e-03 6.23860543e-03 3.78751751e-03 9.60741695e-03
#  6.83012815e-03 3.48956679e-03 1.19550417e-02 1.18973356e-02
#  1.26913229e-02 7.62821725e-03 9.76554200e-03 7.48651104e-03
#  6.11694513e-03 1.73356857e-02 6.58068823e-03 7.51748716e-03
#  4.25446098e-03 3.12817503e-02 2.79544033e-02 3.34148640e-03
#  3.41542145e-05 8.99518482e-03 1.21002636e-02 1.41610791e-02
#  1.74208749e-02 5.25301758e-03 7.72267475e-03 9.80709716e-03
#  1.29165610e-02 5.96703316e-03 4.17135072e-03 1.64072670e-02
#  7.84750212e-03 6.50302860e-03 4.82138737e-04 2.62287372e-02
#  7.05857267e-03 7.02004706e-03 5.51208296e-03 4.05686393e-03
#  6.23418674e-03 1.01150630e-02 1.22382958e-02 8.99093009e-03
#  2.25289965e-02 1.12701289e-02 4.57583451e-03 2.83729506e-03
#  9.77791392e-04 4.36196144e-03 1.26712246e-02 6.60516287e-03
#  4.48700178e-03 1.32675218e-02 6.79822593e-03 6.19656449e-03
#  1.17119616e-02 1.05796586e-02 1.31584034e-02 6.18745851e-03
#  1.75487420e-02 9.78831196e-03 6.50249776e-03 1.08214581e-03
#  2.50746143e-02 1.18581265e-02 1.70623573e-02 1.13153455e-03
#  3.29940801e-03 8.55881138e-03 1.81081673e-03 9.11354213e-03
#  1.28765695e-02 2.11269117e-02 4.81066106e-03 1.97630582e-02
#  3.68395520e-03 5.72626036e-03 4.23821911e-03 5.09893815e-03
#  1.33098653e-02 1.03354837e-02 1.36843665e-02 9.59116074e-03]

# %%
class ScalarStructDist(dists.StructDist):
    def logpdf(self, theta):
        out = super().logpdf(theta)
        if isinstance(out, np.ndarray) and out.shape == (1,):
            return out[0]
        return out

# %%
prior_dict = {'beta': dists.Uniform(a=0.1, b=0.4),
              'gamma': dists.Uniform(a= 0.05, b= 0.15)}  # Uniform distribution because the prior is uninformative

my_prior = ScalarStructDist(prior_dict)      # need this because 'dict' object has no attribute 'dtype' but StructDist does

# %%
# %%capture
pmmh = mcmc.PMMH(ssm_cls= ChainBinomialModel, prior = my_prior, data=y, Nx=5000, niter=1000, adaptive=True, smc_options={"resampling": "systematic", "verbose": True})
pmmh.run()

# %%
# plot the marginals
burnin = 100
for i, param in enumerate(prior_dict.keys()):
    plt.subplot(2, 2, i+1)
    sb.distplot(pmmh.chain.theta[param][burnin:], 40)
    plt.title(param)

# %%
print(len(np.array(y)))
# Out:
# 100

# %%
beta_density = pmmh.chain.theta['beta'][burnin:]
gamma_density = pmmh.chain.theta['gamma'][burnin:]
sb.jointplot(x = beta_density, y = gamma_density, kind = 'kde')
plt.xlabel('beta')
plt.ylabel('gamma')
plt.show()

# %%
plt.style.use('ggplot')
plt.plot(y, label=r'$Y_t$', linestyle='', marker='o')
plt.plot([xt['I']*.05 for xt in x], label=r'$I_t$')
plt.legend()

# %%
df = pd.DataFrame(y)
df.rename(columns={0: 'data'}, inplace=True)
df['date'] = pd.date_range(start = '2024/01/01', periods = len(df), freq='D')
print(df)
# Out:
#     data       date
# 0      0 2024-01-01
# 1      1 2024-01-02
# 2      0 2024-01-03
# 3      1 2024-01-04
# 4      1 2024-01-05
# ..   ...        ...
# 95    17 2024-04-05
# 96     1 2024-04-06
# 97     5 2024-04-07
# 98     8 2024-04-08
# 99    14 2024-04-09
#
# [100 rows x 2 columns]

# %% [markdown]
# # Epydemix SIR Model (custom)

# %%
def stochastic_sir(S_t0, I_t0, R_t0, beta, mu, N, timesteps):
    
    # Simulates a stochastic SIR model using the chain binomial process.
    
    S, I, R = S_t0, I_t0, R_t0
    S_arr, I_arr, R_arr = [S], [I], [R]
    incidence = [0]

    for _ in range(timesteps-1):

        # Infection process (Binomial draw of new infections)
        new_infected = np.random.binomial(S, 1 - np.exp(-beta * I / N))

        # Recovery process
        new_recovered = np.random.binomial(I, 1 - np.exp(-mu))

        # Update compartments
        S -= new_infected
        I += new_infected - new_recovered
        R += new_recovered

        # Store results
        S_arr.append(S)
        I_arr.append(I)
        R_arr.append(R)
        incidence.append(new_infected)

    return {"S": S_arr, "I": I_arr, "R": R_arr, "incidence": incidence}

# %%
Nsim = 50

start = time.time()
sim_results =

# %%
N = 10000
model = stochastic_sir(N - 1, 1, 0, 0.3, 0.1, N, len(df))
print(model)
# Out:
# {'S': [9999, 9999, 9996, 9994, 9994, 9991, 9988, 9985, 9982, 9977, 9975, 9974, 9968, 9964, 9952, 9943, 9934, 9919, 9905, 9889, 9870, 9845, 9810, 9767, 9720, 9671, 9616, 9530, 9449, 9337, 9218, 9057, 8876, 8689, 8479, 8236, 7984, 7665, 7340, 6974, 6605, 6245, 5861, 5439, 5004, 4588, 4200, 3837, 3507, 3183, 2923, 2679, 2444, 2246, 2070, 1888, 1726, 1609, 1507, 1401, 1304, 1223, 1144, 1081, 1010, 957, 916, 870, 837, 803, 770, 743, 719, 692, 674, 656, 635, 617, 600, 593, 584, 574, 562, 556, 550, 540, 534, 530, 527, 523, 521, 518, 514, 509, 504, 501, 497, 494, 493, 492], 'I': [1, 1, 4, 6, 6, 9, 10, 11, 13, 15, 15, 14, 20, 23, 31, 39, 47, 59, 67, 76, 88, 106, 132, 167, 198, 230, 262, 323, 371, 447, 536, 644, 743, 852, 972, 1125, 1279, 1489, 1662, 1839, 2005, 2177, 2374, 2563, 2768, 2896, 3013, 3093, 3122, 3162, 3104, 3059, 3022, 2931, 2818, 2714, 2633, 2494, 2362, 2230, 2119, 1987, 1901, 1788, 1687, 1569, 1436, 1346, 1246, 1145, 1079, 1002, 932, 878, 825, 779, 735, 678, 622, 560, 521, 492, 461, 423, 391, 362, 340, 309, 280, 259, 234, 222, 200, 182, 170, 155, 145, 133, 124, 112], 'R': [0, 0, 0, 0, 0, 0, 2, 4, 5, 8, 10, 12, 12, 13, 17, 18, 19, 22, 28, 35, 42, 49, 58, 66, 82, 99, 122, 147, 180, 216, 246, 299, 381, 459, 549, 639, 737, 846, 998, 1187, 1390, 1578, 1765, 1998, 2228, 2516, 2787, 3070, 3371, 3655, 3973, 4262, 4534, 4823, 5112, 5398, 5641, 5897, 6131, 6369, 6577, 6790, 6955, 7131, 7303, 7474, 7648, 7784, 7917, 8052, 8151, 8255, 8349, 8430, 8501, 8565, 8630, 8705, 8778, 8847, 8895, 8934, 8977, 9021, 9059, 9098, 9126, 9161, 9193, 9218, 9245, 9260, 9286, 9309, 9326, 9344, 9358, 9373, 9383, 9396], 'incidence': [0, 0, 3, 2, 0, 3, 3, 3, 3, 5, 2, 1, 6, 4, 12, 9, 9, 15, 14, 16, 19, 25, 35, 43, 47, 49, 55, 86, 81, 112, 119, 161, 181, 187, 210, 243, 252, 319, 325, 366, 369, 360, 384, 422, 435, 416, 388, 363, 330, 324, 260, 244, 235, 198, 176, 182, 162, 117, 102, 106, 97, 81, 79, 63, 71, 53, 41, 46, 33, 34, 33, 27, 24, 27, 18, 18, 21, 18, 17, 7, 9, 10, 12, 6, 6, 10, 6, 4, 3, 4, 2, 3, 4, 5, 5, 3, 4, 3, 1, 1]}

# %%
data = pd.read_csv('/Users/gabriellebouvier/SIR_Model/Project2/incidence_data.csv')

# %%
# priors
priors = {"beta": stats.uniform(0.1, .4), 
          "mu": stats.uniform(0.05, 0.15)}

# simulation parameters
N = 10000 # population
parameters = {"S_t0": N - 1,
              "I_t0": 1,
              "R_t0": 0,
              "N": N,
              "timesteps": len(df)}

# wrapper function
def simulate_wrapper(parameters): 
    results = stochastic_sir(**parameters)
    return {"data": results["incidence"]}

# initialize the ABCSampler object
abc_sampler = ABCSampler(simulation_function=simulate_wrapper, 
                         priors=priors, 
                         parameters=parameters, 
                         observed_data=df["data"].values)

# %%
print(abc_sampler)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 print(abc_sampler['priors'])
#
# TypeError: 'ABCSampler' object is not subscriptable

# %%
results = abc_sampler.calibrate(strategy="smc", 
                    num_particles=100, 
                    num_generations=5)
# Out:
# Starting ABC-SMC with 100 particles and 5 generations
#
# Generation 1/5 (epsilon: inf)
# 	Accepted 100/100 (acceptance rate: 100.00%)
# 	Elapsed time: 00:00:00
#
# Generation 2/5 (epsilon: 92.916629)
# 	Accepted 100/286 (acceptance rate: 34.97%)
# 	Elapsed time: 00:00:00
#
# Generation 3/5 (epsilon: 92.916414)
# 	Accepted 100/629 (acceptance rate: 15.90%)
# 	Elapsed time: 00:00:00
#
# Generation 4/5 (epsilon: 92.441484)
# 	Accepted 100/1171 (acceptance rate: 8.54%)
# 	Elapsed time: 00:00:00
#
# Generation 5/5 (epsilon: 88.179551)
# 	Accepted 100/2205 (acceptance rate: 4.54%)
# 	Elapsed time: 00:00:00

# %%
df_quantiles_calibration = results.get_calibration_quantiles(df["date"])
plot_quantiles(df_quantiles_calibration, columns="data", data=df, show_legend=True, show_data=True)
# Out:
# <Axes: >

# %%
print(df_quantiles_calibration)
# Out:
#           date  quantile   data
# 0   2024-01-01      0.05   0.00
# 1   2024-01-02      0.05   0.00
# 2   2024-01-03      0.05   0.00
# 3   2024-01-04      0.05   0.00
# 4   2024-01-05      0.05   0.00
# ..         ...       ...    ...
# 295 2024-04-05      0.95  63.05
# 296 2024-04-06      0.95  62.15
# 297 2024-04-07      0.95  61.00
# 298 2024-04-08      0.95  59.90
# 299 2024-04-09      0.95  60.25
#
# [300 rows x 3 columns]

# %%
df_posterior = results.get_posterior_distribution()
plot_posterior_distribution_2d(df_posterior, "beta", "mu", kind="kde")
# Out:
# <Axes: title={'center': 'Joint Distribution\nbeta vs mu'}, xlabel='beta', ylabel='mu'>

# %%
print(df_posterior)
# Out:
#         beta        mu
# 0   0.284481  0.143489
# 1   0.298174  0.156195
# 2   0.364930  0.196767
# 3   0.340245  0.166204
# 4   0.238855  0.109456
# ..       ...       ...
# 95  0.310612  0.175412
# 96  0.254612  0.104662
# 97  0.303875  0.154189
# 98  0.292836  0.122063
# 99  0.309981  0.182514
#
# [100 rows x 2 columns]

# %%
sb.jointplot(x = df_posterior['beta'], y = df_posterior['mu'], kind = 'kde')
plt.xlabel('beta')
plt.ylabel('mu')
plt.show()

# %%
from epydemix.visualization import plot_posterior_distribution

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3), dpi=300)
plot_posterior_distribution(results.get_posterior_distribution(), "beta", ax=axes[0], kind="kde", title="Transmission rate", prior_range=False, label="ABC-SMC")
axes[0].legend()    

plot_posterior_distribution(results.get_posterior_distribution(), "mu", ax=axes[1], kind="kde", title="Recovery rate", prior_range=False, label="ABC-SMC")
axes[1].legend()
